# %% [markdown]
# ## Import Library

# %%
import os
#os.environ["KERAS_BACKEND"] = "plaidml.keras.backend" #for Mac
os.environ["CUDA_VISIBLE_DEVICES"] = '1'
#os.environ["CUDA_VISIBLE_DEVICES"]='1'
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import backend as K
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
pd.options.display.max_columns = None

# %% [markdown]
# ## Load Data and Preprocessing

# %%
import datatable
df_amc = datatable.fread('./1205_asan_raw_v2.csv', na_strings=['']).to_pandas()
df_brmh = datatable.fread('./brmh_1209.csv', na_strings=['']).to_pandas()
df_eumc = datatable.fread('./1205_eumc_raw2.csv', na_strings=['', 'NA']).to_pandas()
df_snuh = datatable.fread("./snuh_2004_2019_v2.csv", na_strings=['']).to_pandas()

## snuh
df_snuh.loc[df_snuh['sex'] == 'M', 'sex'] = 0
df_snuh.loc[df_snuh['sex'] == 'F', 'sex'] = 1

## eumc
df_eumc.loc[df_eumc['sex'] == 2, 'sex'] = 0
df_eumc['death30'] = df_eumc['death_inhosp'].astype(int)

## brmh
df_brmh['sex'] = df_brmh['sex'].astype(int)
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# .datatable .frame thead tr.colnames {  background-image: url('data:image/png;base64,...');  background-repeat: repeat-x;  background-size: 14px;  height: 28px;}
# </style>

# %%
print(df_amc.shape)
print(df_snuh.shape)
print(df_brmh.shape)
print(df_eumc.shape)
# Out:
# (30680, 40)
# (225634, 27)
# (39185, 32)
# (33603, 26)

# %% [markdown]
# ### Variable Selection

# %%
var_list = ['age','bmi','sex', 'preop_alb','preop_bun','preop_cr','preop_glu','preop_gpt','preop_got','preop_hb','preop_k','preop_na','preop_plt','preop_wbc']

# %% [markdown]
# ## Model

# %%
def my_model(hidden_layer_num, node_size, batch_normalization, drop_out, drop_out_rate, learning_rate):
    
    ### clear memory
    if K.backend() == 'tensorflow':
        K.clear_session()
    
    model = keras.Sequential()

    ### Input Layer
    model.add(keras.layers.InputLayer(input_shape=(14,)))
    
    ### Hidden Layer
    for i in range(hidden_layer_num):
        model.add(keras.layers.Dense(node_size))
        if batch_normalization: model.add(keras.layers.BatchNormalization())
        model.add(keras.layers.ReLU())
        if drop_out: model.add(keras.layers.Dropout(drop_out_rate))    
    
    ### Output Layer
    model.add(keras.layers.Dense(1, activation='sigmoid'))
    
    ### Compile
    model.compile(optimizer= keras.optimizers.Adam(learning_rate), 
                  loss='binary_crossentropy', 
                  metrics=["accuracy"])
    
    return model

# %% [markdown]
# ### Display results

# %%
#from sklearn.metrics import plot_roc_curve
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score

def plot_result(X_val, y_val, model, options):
    if options == True:
        tmp_list = []
        y_test_proba = model.predict((X_val))

        tmp_list.append(roc_auc_score(y_val, y_test_proba))
        print("AUROC: {}".format(tmp_list[0]))

        fpr, tpr, _ = roc_curve(y_val, y_test_proba)
        #plot_roc_curve(estimator=model, X=fpr, y=tpr)
        plt.figure(figsize=(10,10))
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('ROC Curve')
        plt.plot(fpr, tpr)
        plt.show()

        tmp_list.append(average_precision_score(y_val, y_test_proba))
        print("AUPRC: {}".format(tmp_list[1]))

        prec, recall, _ = precision_recall_curve(y_val, y_test_proba)

        plt.figure(figsize=(10,10))
        plt.plot(recall, prec)
        plt.xlabel('Recall')
        plt.ylabel('Precision')
        plt.title('Precision-Recall Curve')
        plt.show()
    else:
        tmp_list = []
        y_test_proba = model.predict((X_val))

        tmp_list.append(roc_auc_score(y_val, y_test_proba))
        print("AUROC: {}".format(tmp_list[0]))

        tmp_list.append(average_precision_score(y_val, y_test_proba))
        print("AUPRC: {}".format(tmp_list[1]))
        
    return tmp_list

# %% [markdown]
# ## Transfer Learning - Optimization Test

# %%
snuh_set = {'data':df_snuh, 'build_epoch':15, 'build_batch':2**8}
amc_set = {'data':df_amc, 'build_epoch':3, 'build_batch':2**5}
eumc_set = {'data':df_eumc, 'build_epoch':15, 'build_batch':2**5}
brmh_set = {'data':df_brmh, 'build_epoch':10, 'build_batch':2**5}

# %%
def transfer_test(build_set, val_set_1, val_set_2, val_set_3, variable):
    
    build_data = build_set['data']
    build_epoch = build_set['build_epoch']
    build_batch = build_set['build_batch']
    
    X_data = build_data[variable]
    y_data = build_data['death30']
    
    ## Missing Imputation
    X_data.fillna(X_data.median(), inplace=True)
    
    ## Train Test Split
    X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.2, stratify=y_data, random_state=1004)
    
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = pd.DataFrame(scaler.transform(X_train))
    X_test = pd.DataFrame(scaler.transform(X_test))
    
    #transfer_epoch = [1, 2, 3, 4, 5, 6]
    tune_size = [0.2, 0.4, 0.6, 0.8]
    
    result = []
    
    for val_set in tqdm([val_set_1, val_set_2, val_set_3], desc='data_set'):
        
        val_data = val_set['data']
        
        X_val_set = val_data[variable]
        X_val_set.fillna(X_val_set.median(), inplace=True)
        y_val_set = val_data['death30']
        
        for size in tqdm(tune_size, desc='train_size'):        
            X_tune, X_val, y_tune, y_val = train_test_split(X_val_set, y_val_set, train_size=size, stratify=y_val_set, random_state=1004)
            X_tune = scaler.transform(X_tune)
            X_val = scaler.transform(X_val)
            model = my_model(hidden_layer_num=5, node_size=1000, drop_out=True, drop_out_rate=0.4, batch_normalization=True, learning_rate=0.001)
            for val_batch in [2**5, 2**6, 2**7, 2**8, 2**9, 2**10]:
                ## Build Initial Model
                model.fit(X_train, y_train, batch_size=build_batch, epochs=build_epoch, verbose=0)
                print('\nInternal Validation:')
                result.append(plot_result(X_val=X_test, y_val=y_test, model=model, options=False))

                for epoch_num in range(10):
                    ## Transfer Learning
                    model.fit(X_tune, y_tune, batch_size=val_batch, epochs=1, verbose=0)
                    print('External Validation: train_size = {0}, epoch = {1}, batch_size = {2}'.format(size, epoch_num+1, val_batch))
                    result.append(plot_result(X_val=X_val, y_val=y_val, model=model, options=False))

    return result

# %%
result_snuh = transfer_test(build_set=snuh_set, 
                            val_set_1=amc_set, val_set_2=eumc_set, val_set_3=brmh_set, 
                            variable=var_list)
# Out:
# /home/khl256/anaconda3/envs/deeplearning/lib/python3.7/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# HBox(children=(FloatProgress(value=0.0, description='data_set', max=3.0, style=ProgressStyle(description_width…
# /home/khl256/anaconda3/envs/deeplearning/lib/python3.7/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# HBox(children=(FloatProgress(value=0.0, description='train_size', max=4.0, style=ProgressStyle(description_wid…
# Internal Validation:
# AUROC: 0.930931307088488
# AUPRC: 0.16097492320304022
# External Validation: train_size = 0.2, epoch = 1, batch_size = 32
# AUROC: 0.9266938651978656
# AUPRC: 0.12382356067839169
# External Validation: train_size = 0.2, epoch = 2, batch_size = 32
# AUROC: 0.8418149629418339
# AUPRC: 0.03042418233812497
# External Validation: train_size = 0.2, epoch = 3, batch_size = 32
# AUROC: 0.6629883030245811
# AUPRC: 0.015481288600055636
# External Validation: train_size = 0.2, epoch = 4, batch_size = 32
# AUROC: 0.8381345905455977
# AUPRC: 0.03875915025452585
# External Validation: train_size = 0.2, epoch = 5, batch_size = 32
# AUROC: 0.8467220145393624
# AUPRC: 0.05890968361463278
# External Validation: train_size = 0.2, epoch = 6, batch_size = 32
# AUROC: 0.8446302318838833
# AUPRC: 0.03553625447336624
# External Validation: train_size = 0.2, epoch = 7, batch_size = 32
# AUROC: 0.8612205324135918
# AUPRC: 0.07033047976941943
# External Validation: train_size = 0.2, epoch = 8, batch_size = 32
# AUROC: 0.8270583201592541
# AUPRC: 0.060822195593845586
# External Validation: train_size = 0.2, epoch = 9, batch_size = 32
# AUROC: 0.7222964345283411
# AUPRC: 0.04515035966011965
# External Validation: train_size = 0.2, epoch = 10, batch_size = 32
# AUROC: 0.6910315153438685
# AUPRC: 0.02194655738496508
#
# Internal Validation:
# AUROC: 0.9314973087815651
# AUPRC: 0.14098017921088718
# External Validation: train_size = 0.2, epoch = 1, batch_size = 64
# AUROC: 0.9295724098956587
# AUPRC: 0.07146924617860324
# External Validation: train_size = 0.2, epoch = 2, batch_size = 64
# AUROC: 0.9013614666047969
# AUPRC: 0.09505918110741887
# External Validation: train_size = 0.2, epoch = 3, batch_size = 64
# AUROC: 0.8738368476487197
# AUPRC: 0.0862282501728462
# External Validation: train_size = 0.2, epoch = 4, batch_size = 64
# AUROC: 0.8186138525025394
# AUPRC: 0.06876845170475242
# External Validation: train_size = 0.2, epoch = 5, batch_size = 64
# AUROC: 0.762488257158028
# AUPRC: 0.056492323066623204
# External Validation: train_size = 0.2, epoch = 6, batch_size = 64
# AUROC: 0.7623262176565473
# AUPRC: 0.0341373129006773
# External Validation: train_size = 0.2, epoch = 7, batch_size = 64
# AUROC: 0.7266681531447381
# AUPRC: 0.02790034302603303
# External Validation: train_size = 0.2, epoch = 8, batch_size = 64
# AUROC: 0.7183907468748807
# AUPRC: 0.0287242579204412
# External Validation: train_size = 0.2, epoch = 9, batch_size = 64
# AUROC: 0.62082957528911
# AUPRC: 0.01917951734572829
# External Validation: train_size = 0.2, epoch = 10, batch_size = 64
# AUROC: 0.6515280258031166
# AUPRC: 0.018199103330948627
#
# Internal Validation:
# AUROC: 0.9254549696686887
# AUPRC: 0.1587466094822342
# External Validation: train_size = 0.2, epoch = 1, batch_size = 128
# AUROC: 0.9295536615235864
# AUPRC: 0.1684420134496235
# External Validation: train_size = 0.2, epoch = 2, batch_size = 128
# AUROC: 0.9225732408502922
# AUPRC: 0.14998486237708586
# External Validation: train_size = 0.2, epoch = 3, batch_size = 128
# AUROC: 0.9063619252703279
# AUPRC: 0.12547491456280926
# External Validation: train_size = 0.2, epoch = 4, batch_size = 128
# AUROC: 0.8853262518053677
# AUPRC: 0.09803160178272893
# External Validation: train_size = 0.2, epoch = 5, batch_size = 128
# AUROC: 0.8760551818156861
# AUPRC: 0.08372991119529397
# External Validation: train_size = 0.2, epoch = 6, batch_size = 128
# AUROC: 0.8533234502629125
# AUPRC: 0.08210882223393497
# External Validation: train_size = 0.2, epoch = 7, batch_size = 128
# AUROC: 0.8381198596818267
# AUPRC: 0.07154737043642852
# External Validation: train_size = 0.2, epoch = 8, batch_size = 128
# AUROC: 0.807738792323613
# AUPRC: 0.04203437392621506
# External Validation: train_size = 0.2, epoch = 9, batch_size = 128
# AUROC: 0.8209671079899535
# AUPRC: 0.035161426793835056
# External Validation: train_size = 0.2, epoch = 10, batch_size = 128
# AUROC: 0.8046145100347313
# AUPRC: 0.029252578501785226
#
# Internal Validation:
# AUROC: 0.9184590202947045
# AUPRC: 0.14876259244622608
# External Validation: train_size = 0.2, epoch = 1, batch_size = 256
# AUROC: 0.908499239686554
# AUPRC: 0.14035170150128978
# External Validation: train_size = 0.2, epoch = 2, batch_size = 256
# AUROC: 0.9122201219581604
# AUPRC: 0.1420093644247538
# External Validation: train_size = 0.2, epoch = 3, batch_size = 256
# AUROC: 0.9047194339598638
# AUPRC: 0.12408893632695672
# External Validation: train_size = 0.2, epoch = 4, batch_size = 256
# AUROC: 0.8992864235672393
# AUPRC: 0.11685928715844332
# External Validation: train_size = 0.2, epoch = 5, batch_size = 256
# AUROC: 0.8875532905736532
# AUPRC: 0.10965737749636995
# External Validation: train_size = 0.2, epoch = 6, batch_size = 256
# AUROC: 0.8810596579895182
# AUPRC: 0.10651300175923857
# External Validation: train_size = 0.2, epoch = 7, batch_size = 256
# AUROC: 0.8686227914585095
# AUPRC: 0.09857425794302385
# External Validation: train_size = 0.2, epoch = 8, batch_size = 256
# AUROC: 0.8554828609747949
# AUPRC: 0.09284705922967583
# External Validation: train_size = 0.2, epoch = 9, batch_size = 256
# AUROC: 0.8462666969318957
# AUPRC: 0.0866576272133265
# External Validation: train_size = 0.2, epoch = 10, batch_size = 256
# AUROC: 0.8425317533812354
# AUPRC: 0.08115173264905169
#
# Internal Validation:
# AUROC: 0.9146098145428296
# AUPRC: 0.13023152944982347
# External Validation: train_size = 0.2, epoch = 1, batch_size = 512
# AUROC: 0.9197348712355109
# AUPRC: 0.13243854425480045
# External Validation: train_size = 0.2, epoch = 2, batch_size = 512
# AUROC: 0.9219632491732304
# AUPRC: 0.13528299281321732
# External Validation: train_size = 0.2, epoch = 3, batch_size = 512
# AUROC: 0.919818569325119
# AUPRC: 0.13619280960327834
# External Validation: train_size = 0.2, epoch = 4, batch_size = 512
# AUROC: 0.9175212241615628
# AUPRC: 0.12542052943519877
# External Validation: train_size = 0.2, epoch = 5, batch_size = 512
# AUROC: 0.9157086583330152
# AUPRC: 0.11865292398949297
# External Validation: train_size = 0.2, epoch = 6, batch_size = 512
# AUROC: 0.9123158725726717
# AUPRC: 0.11579495074629202
# External Validation: train_size = 0.2, epoch = 7, batch_size = 512
# AUROC: 0.9087844827759374
# AUPRC: 0.1073729181027327
# External Validation: train_size = 0.2, epoch = 8, batch_size = 512
# AUROC: 0.9052363533612817
# AUPRC: 0.10296897708179346
# External Validation: train_size = 0.2, epoch = 9, batch_size = 512
# AUROC: 0.9025975199921256
# AUPRC: 0.09858666906944642
# External Validation: train_size = 0.2, epoch = 10, batch_size = 512
# AUROC: 0.8988598981025978
# AUPRC: 0.09327023180366854
#
# Internal Validation:
# AUROC: 0.9109801282065066
# AUPRC: 0.12676647524192108
# External Validation: train_size = 0.2, epoch = 1, batch_size = 1024
# AUROC: 0.9080573137734246
# AUPRC: 0.15535260623162478
# External Validation: train_size = 0.2, epoch = 2, batch_size = 1024
# AUROC: 0.9111353947168428
# AUPRC: 0.15559092935574162
# External Validation: train_size = 0.2, epoch = 3, batch_size = 1024
# AUROC: 0.9138632828533415
# AUPRC: 0.15829646209452833
# External Validation: train_size = 0.2, epoch = 4, batch_size = 1024
# AUROC: 0.9159530567546701
# AUPRC: 0.1609631376788727
# External Validation: train_size = 0.2, epoch = 5, batch_size = 1024
# AUROC: 0.9165262212723047
# AUPRC: 0.15937333135743625
# External Validation: train_size = 0.2, epoch = 6, batch_size = 1024
# AUROC: 0.9161800459736866
# AUPRC: 0.1570148989695405
# External Validation: train_size = 0.2, epoch = 7, batch_size = 1024
# AUROC: 0.9153048987487471
# AUPRC: 0.154913362785558
# External Validation: train_size = 0.2, epoch = 8, batch_size = 1024
# AUROC: 0.9141284384012192
# AUPRC: 0.1547363809162167
# External Validation: train_size = 0.2, epoch = 9, batch_size = 1024
# AUROC: 0.9126794570739282
# AUPRC: 0.15353199433623962
# External Validation: train_size = 0.2, epoch = 10, batch_size = 1024
# AUROC: 0.9113135042515281
# AUPRC: 0.1511200573478607
#
# Internal Validation:
# AUROC: 0.9215532584566046
# AUPRC: 0.13826217058937215
# External Validation: train_size = 0.4, epoch = 1, batch_size = 32
# AUROC: 0.8997267513721627
# AUPRC: 0.05235328647316591
# External Validation: train_size = 0.4, epoch = 2, batch_size = 32
# AUROC: 0.8409664571918376
# AUPRC: 0.013385600742903951
# External Validation: train_size = 0.4, epoch = 3, batch_size = 32
# AUROC: 0.8793911575418042
# AUPRC: 0.07032093418735948
# External Validation: train_size = 0.4, epoch = 4, batch_size = 32
# AUROC: 0.9301558511671079
# AUPRC: 0.0931434858347349
# External Validation: train_size = 0.4, epoch = 5, batch_size = 32
# AUROC: 0.9270551659144831
# AUPRC: 0.08751729170605538
# External Validation: train_size = 0.4, epoch = 6, batch_size = 32
# AUROC: 0.9138260490710968
# AUPRC: 0.06084991965273888
# External Validation: train_size = 0.4, epoch = 7, batch_size = 32
# AUROC: 0.9192566879614327
# AUPRC: 0.08274970740798694
# External Validation: train_size = 0.4, epoch = 8, batch_size = 32
# AUROC: 0.8695699530694299
# AUPRC: 0.08382276301558685
# External Validation: train_size = 0.4, epoch = 9, batch_size = 32
# AUROC: 0.9343398227909245
# AUPRC: 0.1103804858317609
# External Validation: train_size = 0.4, epoch = 10, batch_size = 32
# AUROC: 0.8700281299280652
# AUPRC: 0.07459577063765044
#
# Internal Validation:
# AUROC: 0.9322598027515012
# AUPRC: 0.16127313685203523
# External Validation: train_size = 0.4, epoch = 1, batch_size = 64
# AUROC: 0.9411994525556087
# AUPRC: 0.12997524442507505
# External Validation: train_size = 0.4, epoch = 2, batch_size = 64
# AUROC: 0.9264466312753654
# AUPRC: 0.12443744395908815
# External Validation: train_size = 0.4, epoch = 3, batch_size = 64
# AUROC: 0.9247607298627127
# AUPRC: 0.14192239074527038
# External Validation: train_size = 0.4, epoch = 4, batch_size = 64
# AUROC: 0.9024438466966278
# AUPRC: 0.11034234004598015
# External Validation: train_size = 0.4, epoch = 5, batch_size = 64
# AUROC: 0.8842410839020093
# AUPRC: 0.11673540957356614
# External Validation: train_size = 0.4, epoch = 6, batch_size = 64
# AUROC: 0.868464172227142
# AUPRC: 0.05433390036152657
# External Validation: train_size = 0.4, epoch = 7, batch_size = 64
# AUROC: 0.848214412562807
# AUPRC: 0.05089011293505208
# External Validation: train_size = 0.4, epoch = 8, batch_size = 64
# AUROC: 0.8608196038131679
# AUPRC: 0.05416819808192923
# External Validation: train_size = 0.4, epoch = 9, batch_size = 64
# AUROC: 0.8372122483579035
# AUPRC: 0.038366312562505576
# External Validation: train_size = 0.4, epoch = 10, batch_size = 64
# AUROC: 0.847468543258052
# AUPRC: 0.0376142707111767
#
# Internal Validation:
# AUROC: 0.926803983677074
# AUPRC: 0.14687338903207087
# External Validation: train_size = 0.4, epoch = 1, batch_size = 128
# AUROC: 0.9388399009296137
# AUPRC: 0.13613894303156904
# External Validation: train_size = 0.4, epoch = 2, batch_size = 128
# AUROC: 0.9304352561765082
# AUPRC: 0.11899463266852135
# External Validation: train_size = 0.4, epoch = 3, batch_size = 128
# AUROC: 0.9299829989155297
# AUPRC: 0.10922820014320332
# External Validation: train_size = 0.4, epoch = 4, batch_size = 128
# AUROC: 0.9188636266770219
# AUPRC: 0.0969822109531852
# External Validation: train_size = 0.4, epoch = 5, batch_size = 128
# AUROC: 0.9034004536779644
# AUPRC: 0.0512450909443263
# External Validation: train_size = 0.4, epoch = 6, batch_size = 128
# AUROC: 0.8932530793747011
# AUPRC: 0.0452217906821218
# External Validation: train_size = 0.4, epoch = 7, batch_size = 128
# AUROC: 0.8953876862897383
# AUPRC: 0.05482780611205724
# External Validation: train_size = 0.4, epoch = 8, batch_size = 128
# AUROC: 0.890624778015088
# AUPRC: 0.04539442535533152
# External Validation: train_size = 0.4, epoch = 9, batch_size = 128
# AUROC: 0.8916997769495603
# AUPRC: 0.042851871953800046
# External Validation: train_size = 0.4, epoch = 10, batch_size = 128
# AUROC: 0.86384806997438
# AUPRC: 0.01827441227359132
#
# Internal Validation:
# AUROC: 0.9190666858768556
# AUPRC: 0.13629270244906586
# External Validation: train_size = 0.4, epoch = 1, batch_size = 256
# AUROC: 0.9287019979826012
# AUPRC: 0.12001445811472895
# External Validation: train_size = 0.4, epoch = 2, batch_size = 256
# AUROC: 0.9249773871369511
# AUPRC: 0.11709698547088389
# External Validation: train_size = 0.4, epoch = 3, batch_size = 256
# AUROC: 0.9199634879216531
# AUPRC: 0.10599110866248466
# External Validation: train_size = 0.4, epoch = 4, batch_size = 256
# AUROC: 0.919105146261419
# AUPRC: 0.10064074840978682
# External Validation: train_size = 0.4, epoch = 5, batch_size = 256
# AUROC: 0.9115896250763628
# AUPRC: 0.08845534362540361
# External Validation: train_size = 0.4, epoch = 6, batch_size = 256
# AUROC: 0.902507778351321
# AUPRC: 0.07466460715698338
# External Validation: train_size = 0.4, epoch = 7, batch_size = 256
# AUROC: 0.9061986474903273
# AUPRC: 0.06705295108109308
# External Validation: train_size = 0.4, epoch = 8, batch_size = 256
# AUROC: 0.8986517524376902
# AUPRC: 0.04464421281433476
# External Validation: train_size = 0.4, epoch = 9, batch_size = 256
# AUROC: 0.8848141009551863
# AUPRC: 0.033079533309127336
# External Validation: train_size = 0.4, epoch = 10, batch_size = 256
# AUROC: 0.8725202805415722
# AUPRC: 0.028551846440913707
#
# Internal Validation:
# AUROC: 0.9123669533142237
# AUPRC: 0.1187082847929351
# External Validation: train_size = 0.4, epoch = 1, batch_size = 512
# AUROC: 0.923376727930556
# AUPRC: 0.12286689033925084
# External Validation: train_size = 0.4, epoch = 2, batch_size = 512
# AUROC: 0.923376727930556
# AUPRC: 0.12777384389665794
# External Validation: train_size = 0.4, epoch = 3, batch_size = 512
# AUROC: 0.9207590818467251
# AUPRC: 0.11727088274935532
# External Validation: train_size = 0.4, epoch = 4, batch_size = 512
# AUROC: 0.9203080085052778
# AUPRC: 0.11481861861753846
# External Validation: train_size = 0.4, epoch = 5, batch_size = 512
# AUROC: 0.9163998901322674
# AUPRC: 0.10347497320403468
# External Validation: train_size = 0.4, epoch = 6, batch_size = 512
# AUROC: 0.9162838660181946
# AUPRC: 0.09841431851716934
# External Validation: train_size = 0.4, epoch = 7, batch_size = 512
# AUROC: 0.9134164129132472
# AUPRC: 0.08290079291108736
# External Validation: train_size = 0.4, epoch = 8, batch_size = 512
# AUROC: 0.911799178833413
# AUPRC: 0.07538883836191408
# External Validation: train_size = 0.4, epoch = 9, batch_size = 512
# AUROC: 0.9101701055582654
# AUPRC: 0.07070723944110913
# External Validation: train_size = 0.4, epoch = 10, batch_size = 512
# AUROC: 0.9086025960987484
# AUPRC: 0.06518493238649858
#
# Internal Validation:
# AUROC: 0.9117542701454311
# AUPRC: 0.11676448979506246
# External Validation: train_size = 0.4, epoch = 1, batch_size = 1024
# AUROC: 0.9239379057884195
# AUPRC: 0.11359509843814136
# External Validation: train_size = 0.4, epoch = 2, batch_size = 1024
# AUROC: 0.9264146654480189
# AUPRC: 0.11597038407175346
# External Validation: train_size = 0.4, epoch = 3, batch_size = 1024
# AUROC: 0.9264525508730224
# AUPRC: 0.11982372069367289
# External Validation: train_size = 0.4, epoch = 4, batch_size = 1024
# AUROC: 0.9256285428791975
# AUPRC: 0.11826413647014154
# External Validation: train_size = 0.4, epoch = 5, batch_size = 1024
# AUROC: 0.9248625469424093
# AUPRC: 0.11705456317127597
# External Validation: train_size = 0.4, epoch = 6, batch_size = 1024
# AUROC: 0.9240906314079645
# AUPRC: 0.11545290071019759
# External Validation: train_size = 0.4, epoch = 7, batch_size = 1024
# AUROC: 0.9229481490602047
# AUPRC: 0.11644369977917418
# External Validation: train_size = 0.4, epoch = 8, batch_size = 1024
# AUROC: 0.9214990315538234
# AUPRC: 0.10658145489036157
# External Validation: train_size = 0.4, epoch = 9, batch_size = 1024
# AUROC: 0.9203091924248091
# AUPRC: 0.10035493529670639
# External Validation: train_size = 0.4, epoch = 10, batch_size = 1024
# AUROC: 0.9195574035223975
# AUPRC: 0.09534728068528166
#
# Internal Validation:
# AUROC: 0.9422635265175869
# AUPRC: 0.15621368774303138
# External Validation: train_size = 0.6, epoch = 1, batch_size = 32
# AUROC: 0.47912922725044926
# AUPRC: 0.0037890727271230632
# External Validation: train_size = 0.6, epoch = 2, batch_size = 32
# AUROC: 0.8843271796547405
# AUPRC: 0.0807843892469221
# External Validation: train_size = 0.6, epoch = 3, batch_size = 32
# AUROC: 0.8754479115612916
# AUPRC: 0.029683927808369155
# External Validation: train_size = 0.6, epoch = 4, batch_size = 32
# AUROC: 0.8765751783477645
# AUPRC: 0.03679107950302448
# External Validation: train_size = 0.6, epoch = 5, batch_size = 32
# AUROC: 0.892653705821489
# AUPRC: 0.09590897421351335
# External Validation: train_size = 0.6, epoch = 6, batch_size = 32
# AUROC: 0.9242498502423351
# AUPRC: 0.09909390378668002
# External Validation: train_size = 0.6, epoch = 7, batch_size = 32
# AUROC: 0.9181996405816043
# AUPRC: 0.09430849128806063
# External Validation: train_size = 0.6, epoch = 8, batch_size = 32
# AUROC: 0.8640445460981322
# AUPRC: 0.04953884581009254
# External Validation: train_size = 0.6, epoch = 9, batch_size = 32
# AUROC: 0.8666503294668626
# AUPRC: 0.06617602551184648
# External Validation: train_size = 0.6, epoch = 10, batch_size = 32
# AUROC: 0.8976746718945707
# AUPRC: 0.04419387313240425
#
# Internal Validation:
# AUROC: 0.9302089538116813
# AUPRC: 0.15168028472511327
# External Validation: train_size = 0.6, epoch = 1, batch_size = 64
# AUROC: 0.9113924739966237
# AUPRC: 0.038757617396398415
# External Validation: train_size = 0.6, epoch = 2, batch_size = 64
# AUROC: 0.912337308718619
# AUPRC: 0.0972813023791397
# External Validation: train_size = 0.6, epoch = 3, batch_size = 64
# AUROC: 0.9062462560583782
# AUPRC: 0.08490535691237727
# External Validation: train_size = 0.6, epoch = 4, batch_size = 64
# AUROC: 0.875728366824593
# AUPRC: 0.07602220030981688
# External Validation: train_size = 0.6, epoch = 5, batch_size = 64
# AUROC: 0.8911561291727932
# AUPRC: 0.07150027331261141
# External Validation: train_size = 0.6, epoch = 6, batch_size = 64
# AUROC: 0.8833523933997712
# AUPRC: 0.06861424205477451
# External Validation: train_size = 0.6, epoch = 7, batch_size = 64
# AUROC: 0.8947557588629309
# AUPRC: 0.07150251595351492
# External Validation: train_size = 0.6, epoch = 8, batch_size = 64
# AUROC: 0.8907150247780865
# AUPRC: 0.07640565906624686
# External Validation: train_size = 0.6, epoch = 9, batch_size = 64
# AUROC: 0.8935468060774384
# AUPRC: 0.07237087889207126
# External Validation: train_size = 0.6, epoch = 10, batch_size = 64
# AUROC: 0.8888199096008278
# AUPRC: 0.06632784383105823
#
# Internal Validation:
# AUROC: 0.9236258801384567
# AUPRC: 0.1674658097938938
# External Validation: train_size = 0.6, epoch = 1, batch_size = 128
# AUROC: 0.9117110493928008
# AUPRC: 0.08426056579874536
# External Validation: train_size = 0.6, epoch = 2, batch_size = 128
# AUROC: 0.9086287643631215
# AUPRC: 0.07349072897886764
# External Validation: train_size = 0.6, epoch = 3, batch_size = 128
# AUROC: 0.8894298317268421
# AUPRC: 0.03146193926830808
# External Validation: train_size = 0.6, epoch = 4, batch_size = 128
# AUROC: 0.8886864891357622
# AUPRC: 0.07553197725072774
# External Validation: train_size = 0.6, epoch = 5, batch_size = 128
# AUROC: 0.8907749278440342
# AUPRC: 0.07119654322255463
# External Validation: train_size = 0.6, epoch = 6, batch_size = 128
# AUROC: 0.8646326852910745
# AUPRC: 0.07032220275891354
# External Validation: train_size = 0.6, epoch = 7, batch_size = 128
# AUROC: 0.8895006262593258
# AUPRC: 0.07271466533184115
# External Validation: train_size = 0.6, epoch = 8, batch_size = 128
# AUROC: 0.8700076240265752
# AUPRC: 0.06664836759723519
# External Validation: train_size = 0.6, epoch = 9, batch_size = 128
# AUROC: 0.8604530850078963
# AUPRC: 0.06646124507631869
# External Validation: train_size = 0.6, epoch = 10, batch_size = 128
# AUROC: 0.8481647878886892
# AUPRC: 0.06968211938173394
#
# Internal Validation:
# AUROC: 0.912416053983498
# AUPRC: 0.1361495759977117
# External Validation: train_size = 0.6, epoch = 1, batch_size = 256
# AUROC: 0.912340031585253
# AUPRC: 0.09069804432547789
# External Validation: train_size = 0.6, epoch = 2, batch_size = 256
# AUROC: 0.912301911452377
# AUPRC: 0.0844086616266641
# External Validation: train_size = 0.6, epoch = 3, batch_size = 256
# AUROC: 0.9114442084626695
# AUPRC: 0.08603216263243064
# External Validation: train_size = 0.6, epoch = 4, batch_size = 256
# AUROC: 0.9111991504656103
# AUPRC: 0.08292019567728892
# External Validation: train_size = 0.6, epoch = 5, batch_size = 256
# AUROC: 0.897173664433916
# AUPRC: 0.08164144351819612
# External Validation: train_size = 0.6, epoch = 6, batch_size = 256
# AUROC: 0.8885203942710886
# AUPRC: 0.05019242630501735
# External Validation: train_size = 0.6, epoch = 7, batch_size = 256
# AUROC: 0.8913303926373686
# AUPRC: 0.045123129576802916
# External Validation: train_size = 0.6, epoch = 8, batch_size = 256
# AUROC: 0.8865299787616403
# AUPRC: 0.039316819839267325
# External Validation: train_size = 0.6, epoch = 9, batch_size = 256
# AUROC: 0.8705576430866416
# AUPRC: 0.036381070817336256
# External Validation: train_size = 0.6, epoch = 10, batch_size = 256
# AUROC: 0.8699232151609214
# AUPRC: 0.030652221917794834
#
# Internal Validation:
# AUROC: 0.9121443875067827
# AUPRC: 0.13496480260993582
# External Validation: train_size = 0.6, epoch = 1, batch_size = 512
# AUROC: 0.9010319664542831
# AUPRC: 0.10152154193283695
# External Validation: train_size = 0.6, epoch = 2, batch_size = 512
# AUROC: 0.9032238740946469
# AUPRC: 0.08709198788225332
# External Validation: train_size = 0.6, epoch = 3, batch_size = 512
# AUROC: 0.905998475194685
# AUPRC: 0.08320670970529365
# External Validation: train_size = 0.6, epoch = 4, batch_size = 512
# AUROC: 0.9088057506943309
# AUPRC: 0.08057287049215522
# External Validation: train_size = 0.6, epoch = 5, batch_size = 512
# AUROC: 0.9078336873059957
# AUPRC: 0.07737257113754106
# External Validation: train_size = 0.6, epoch = 6, batch_size = 512
# AUROC: 0.9065512171213854
# AUPRC: 0.05047904112216572
# External Validation: train_size = 0.6, epoch = 7, batch_size = 512
# AUROC: 0.9082148886347546
# AUPRC: 0.07449026316626163
# External Validation: train_size = 0.6, epoch = 8, batch_size = 512
# AUROC: 0.9060502096607308
# AUPRC: 0.04479159525654473
# External Validation: train_size = 0.6, epoch = 9, batch_size = 512
# AUROC: 0.9065430485214835
# AUPRC: 0.03976291020395135
# External Validation: train_size = 0.6, epoch = 10, batch_size = 512
# AUROC: 0.9082829603006045
# AUPRC: 0.04185237690846499
#
# Internal Validation:
# AUROC: 0.903820928067161
# AUPRC: 0.11415907717024007
# External Validation: train_size = 0.6, epoch = 1, batch_size = 1024
# AUROC: 0.90842999509884
# AUPRC: 0.0857209921372656
# External Validation: train_size = 0.6, epoch = 2, batch_size = 1024
# AUROC: 0.9107226488046616
# AUPRC: 0.0871364927511616
# External Validation: train_size = 0.6, epoch = 3, batch_size = 1024
# AUROC: 0.9092523008223058
# AUPRC: 0.08982284828795972
# External Validation: train_size = 0.6, epoch = 4, batch_size = 1024
# AUROC: 0.9076104122420084
# AUPRC: 0.08520008723501742
# External Validation: train_size = 0.6, epoch = 5, batch_size = 1024
# AUROC: 0.9055600936666122
# AUPRC: 0.08304823128760533
# External Validation: train_size = 0.6, epoch = 6, batch_size = 1024
# AUROC: 0.905990306594783
# AUPRC: 0.08104839050961431
# External Validation: train_size = 0.6, epoch = 7, batch_size = 1024
# AUROC: 0.9047296193432446
# AUPRC: 0.06481532350726579
# External Validation: train_size = 0.6, epoch = 8, batch_size = 1024
# AUROC: 0.9034063061591243
# AUPRC: 0.051279873947887855
# External Validation: train_size = 0.6, epoch = 9, batch_size = 1024
# AUROC: 0.9013559875837281
# AUPRC: 0.05177143587964719
# External Validation: train_size = 0.6, epoch = 10, batch_size = 1024
# AUROC: 0.8997059304035289
# AUPRC: 0.0562115687143729
#
# Internal Validation:
# AUROC: 0.933155173167667
# AUPRC: 0.15695657443284547
# External Validation: train_size = 0.8, epoch = 1, batch_size = 32
# AUROC: 0.8761422425529598
# AUPRC: 0.03409052016710595
# External Validation: train_size = 0.8, epoch = 2, batch_size = 32
# AUROC: 0.926754887545608
# AUPRC: 0.06073165012668767
# External Validation: train_size = 0.8, epoch = 3, batch_size = 32
# AUROC: 0.8038120132875892
# AUPRC: 0.09402809037417299
# External Validation: train_size = 0.8, epoch = 4, batch_size = 32
# AUROC: 0.8301693623046343
# AUPRC: 0.04305070149329416
# External Validation: train_size = 0.8, epoch = 5, batch_size = 32
# AUROC: 0.9117682295921146
# AUPRC: 0.03328555477903557
# External Validation: train_size = 0.8, epoch = 6, batch_size = 32
# AUROC: 0.8355170723737951
# AUPRC: 0.05106319006176091
# External Validation: train_size = 0.8, epoch = 7, batch_size = 32
# AUROC: 0.8015139138484998
# AUPRC: 0.035335921549264675
# External Validation: train_size = 0.8, epoch = 8, batch_size = 32
# AUROC: 0.8820780918150629
# AUPRC: 0.1044750496835861
# External Validation: train_size = 0.8, epoch = 9, batch_size = 32
# AUROC: 0.8442955944017863
# AUPRC: 0.025715908448418614
# External Validation: train_size = 0.8, epoch = 10, batch_size = 32
# AUROC: 0.8215868866742907
# AUPRC: 0.04969855756106924
#
# Internal Validation:
# AUROC: 0.9289719395051083
# AUPRC: 0.16240476349420394
# External Validation: train_size = 0.8, epoch = 1, batch_size = 64
# AUROC: 0.9428742580188423
# AUPRC: 0.11665757685303133
# External Validation: train_size = 0.8, epoch = 2, batch_size = 64
# AUROC: 0.9398464303218428
# AUPRC: 0.10416733568505972
# External Validation: train_size = 0.8, epoch = 3, batch_size = 64
# AUROC: 0.9013342046506563
# AUPRC: 0.08535847978687415
# External Validation: train_size = 0.8, epoch = 4, batch_size = 64
# AUROC: 0.9153733050155204
# AUPRC: 0.09357246129273077
# External Validation: train_size = 0.8, epoch = 5, batch_size = 64
# AUROC: 0.9131514458421827
# AUPRC: 0.09052762374583685
# External Validation: train_size = 0.8, epoch = 6, batch_size = 64
# AUROC: 0.8988727332135272
# AUPRC: 0.09494236372162136
# External Validation: train_size = 0.8, epoch = 7, batch_size = 64
# AUROC: 0.8393181941948483
# AUPRC: 0.019132013389747377
# External Validation: train_size = 0.8, epoch = 8, batch_size = 64
# AUROC: 0.8234493274519414
# AUPRC: 0.01792619428111705
# External Validation: train_size = 0.8, epoch = 9, batch_size = 64
# AUROC: 0.7843816369874202
# AUPRC: 0.011672198340424496
# External Validation: train_size = 0.8, epoch = 10, batch_size = 64
# AUROC: 0.7879213636116104
# AUPRC: 0.01750945401251996
#
# Internal Validation:
# AUROC: 0.9258318262653458
# AUPRC: 0.15636155165526677
# External Validation: train_size = 0.8, epoch = 1, batch_size = 128
# AUROC: 0.916516909001797
# AUPRC: 0.042103461459007945
# External Validation: train_size = 0.8, epoch = 2, batch_size = 128
# AUROC: 0.8776670478679954
# AUPRC: 0.023424180033760136
# External Validation: train_size = 0.8, epoch = 3, batch_size = 128
# AUROC: 0.8410826117736754
# AUPRC: 0.023701332603500172
# External Validation: train_size = 0.8, epoch = 4, batch_size = 128
# AUROC: 0.9228230681261231
# AUPRC: 0.09986412201130883
# External Validation: train_size = 0.8, epoch = 5, batch_size = 128
# AUROC: 0.7997059304035289
# AUPRC: 0.015763560693434316
# External Validation: train_size = 0.8, epoch = 6, batch_size = 128
# AUROC: 0.8065784457877253
# AUPRC: 0.016461896725902862
# External Validation: train_size = 0.8, epoch = 7, batch_size = 128
# AUROC: 0.852812721232914
# AUPRC: 0.01910503794422142
# External Validation: train_size = 0.8, epoch = 8, batch_size = 128
# AUROC: 0.8026901922343844
# AUPRC: 0.014936129363439231
# External Validation: train_size = 0.8, epoch = 9, batch_size = 128
# AUROC: 0.7903392691825956
# AUPRC: 0.012819160922522084
# External Validation: train_size = 0.8, epoch = 10, batch_size = 128
# AUROC: 0.7613679681969177
# AUPRC: 0.011757796723461774
#
# Internal Validation:
# AUROC: 0.9147184094537067
# AUPRC: 0.15503873463940582
# External Validation: train_size = 0.8, epoch = 1, batch_size = 256
# AUROC: 0.9231171377225944
# AUPRC: 0.10830016630415104
# External Validation: train_size = 0.8, epoch = 2, batch_size = 256
# AUROC: 0.926025159287698
# AUPRC: 0.10151202036404346
# External Validation: train_size = 0.8, epoch = 3, batch_size = 256
# AUROC: 0.9157871807438872
# AUPRC: 0.09075820968646917
# External Validation: train_size = 0.8, epoch = 4, batch_size = 256
# AUROC: 0.9146871426237543
# AUPRC: 0.09249296923766258
# External Validation: train_size = 0.8, epoch = 5, batch_size = 256
# AUROC: 0.9196863257637641
# AUPRC: 0.09738832651496178
# External Validation: train_size = 0.8, epoch = 6, batch_size = 256
# AUROC: 0.9125633066492403
# AUPRC: 0.09388834728629408
# External Validation: train_size = 0.8, epoch = 7, batch_size = 256
# AUROC: 0.899635135871045
# AUPRC: 0.03839323989205689
# External Validation: train_size = 0.8, epoch = 8, batch_size = 256
# AUROC: 0.8902358002505038
# AUPRC: 0.030889184942639474
# External Validation: train_size = 0.8, epoch = 9, batch_size = 256
# AUROC: 0.8815879758209444
# AUPRC: 0.02204688120147183
# External Validation: train_size = 0.8, epoch = 10, batch_size = 256
# AUROC: 0.8981212220225454
# AUPRC: 0.08657733018433422
#
# Internal Validation:
# AUROC: 0.9143519464293779
# AUPRC: 0.1467194476104111
# External Validation: train_size = 0.8, epoch = 1, batch_size = 512
# AUROC: 0.9230191145237706
# AUPRC: 0.10255878344049131
# External Validation: train_size = 0.8, epoch = 2, batch_size = 512
# AUROC: 0.9272232206066547
# AUPRC: 0.10008909015656364
# External Validation: train_size = 0.8, epoch = 3, batch_size = 512
# AUROC: 0.9290529869846975
# AUPRC: 0.0986643114308995
# External Validation: train_size = 0.8, epoch = 4, batch_size = 512
# AUROC: 0.9247072918368457
# AUPRC: 0.05067080821066502
# External Validation: train_size = 0.8, epoch = 5, batch_size = 512
# AUROC: 0.9213200457441595
# AUPRC: 0.04277453681937824
# External Validation: train_size = 0.8, epoch = 6, batch_size = 512
# AUROC: 0.916222839405326
# AUPRC: 0.033189240247803696
# External Validation: train_size = 0.8, epoch = 7, batch_size = 512
# AUROC: 0.917954582584545
# AUPRC: 0.03236366354223363
# External Validation: train_size = 0.8, epoch = 8, batch_size = 512
# AUROC: 0.9177476447203616
# AUPRC: 0.03086738889441073
# External Validation: train_size = 0.8, epoch = 9, batch_size = 512
# AUROC: 0.9162446223383979
# AUPRC: 0.03033083761026833
# External Validation: train_size = 0.8, epoch = 10, batch_size = 512
# AUROC: 0.9055274192670043
# AUPRC: 0.02230014254066884
#
# Internal Validation:
# AUROC: 0.9035282952462668
# AUPRC: 0.11876616462682629
# External Validation: train_size = 0.8, epoch = 1, batch_size = 1024
# AUROC: 0.9121712138539455
# AUPRC: 0.11183298854235779
# External Validation: train_size = 0.8, epoch = 2, batch_size = 1024
# AUROC: 0.914055437564668
# AUPRC: 0.10426996171176889
# External Validation: train_size = 0.8, epoch = 3, batch_size = 1024
# AUROC: 0.9157000490115994
# AUPRC: 0.10108670682985425
# External Validation: train_size = 0.8, epoch = 4, batch_size = 1024
# AUROC: 0.9164842346021893
# AUPRC: 0.0986407653895044
# External Validation: train_size = 0.8, epoch = 5, batch_size = 1024
# AUROC: 0.9168109785982683
# AUPRC: 0.09727832820981776
# External Validation: train_size = 0.8, epoch = 6, batch_size = 1024
# AUROC: 0.9153624135489844
# AUPRC: 0.09466824890203823
# External Validation: train_size = 0.8, epoch = 7, batch_size = 1024
# AUROC: 0.9155911343462396
# AUPRC: 0.0940999301940438
# External Validation: train_size = 0.8, epoch = 8, batch_size = 1024
# AUROC: 0.9146980340902903
# AUPRC: 0.0926568452510038
# External Validation: train_size = 0.8, epoch = 9, batch_size = 1024
# AUROC: 0.9129009421118555
# AUPRC: 0.09165314193451249
# External Validation: train_size = 0.8, epoch = 10, batch_size = 1024
# AUROC: 0.9120296247889779
# AUPRC: 0.09100059627261496
# /home/khl256/anaconda3/envs/deeplearning/lib/python3.7/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# HBox(children=(FloatProgress(value=0.0, description='train_size', max=4.0, style=ProgressStyle(description_wid…
# Internal Validation:
# AUROC: 0.9334268396443821
# AUPRC: 0.1571790693346748
# External Validation: train_size = 0.2, epoch = 1, batch_size = 32
# AUROC: 0.901260177655562
# AUPRC: 0.23055600914334798
# External Validation: train_size = 0.2, epoch = 2, batch_size = 32
# AUROC: 0.9065152059286419
# AUPRC: 0.21313587095004208
# External Validation: train_size = 0.2, epoch = 3, batch_size = 32
# AUROC: 0.899635631999117
# AUPRC: 0.2170659022063235
# External Validation: train_size = 0.2, epoch = 4, batch_size = 32
# AUROC: 0.8986062354078834
# AUPRC: 0.24098652058639247
# External Validation: train_size = 0.2, epoch = 5, batch_size = 32
# AUROC: 0.8693224218894346
# AUPRC: 0.22697377033709534
# External Validation: train_size = 0.2, epoch = 6, batch_size = 32
# AUROC: 0.8229217240006708
# AUPRC: 0.16717505083181547
# External Validation: train_size = 0.2, epoch = 7, batch_size = 32
# AUROC: 0.8777051654593052
# AUPRC: 0.20699421904048085
# External Validation: train_size = 0.2, epoch = 8, batch_size = 32
# AUROC: 0.8638756315085472
# AUPRC: 0.19287814998869873
# External Validation: train_size = 0.2, epoch = 9, batch_size = 32
# AUROC: 0.8192445172833849
# AUPRC: 0.15880131627724914
# External Validation: train_size = 0.2, epoch = 10, batch_size = 32
# AUROC: 0.8713694174031212
# AUPRC: 0.2091126662315356
#
# Internal Validation:
# AUROC: 0.9283295092155147
# AUPRC: 0.16192346182344375
# External Validation: train_size = 0.2, epoch = 1, batch_size = 64
# AUROC: 0.9030172304619275
# AUPRC: 0.22236895243782873
# External Validation: train_size = 0.2, epoch = 2, batch_size = 64
# AUROC: 0.8985087879968252
# AUPRC: 0.2360097239596994
# External Validation: train_size = 0.2, epoch = 3, batch_size = 64
# AUROC: 0.8838359540154864
# AUPRC: 0.22465235716650095
# External Validation: train_size = 0.2, epoch = 4, batch_size = 64
# AUROC: 0.8489439153489937
# AUPRC: 0.20999803037523085
# External Validation: train_size = 0.2, epoch = 5, batch_size = 64
# AUROC: 0.86169432920055
# AUPRC: 0.22250624535543234
# External Validation: train_size = 0.2, epoch = 6, batch_size = 64
# AUROC: 0.8382760233244578
# AUPRC: 0.18201346691838718
# External Validation: train_size = 0.2, epoch = 7, batch_size = 64
# AUROC: 0.8691375917452044
# AUPRC: 0.22261143778538028
# External Validation: train_size = 0.2, epoch = 8, batch_size = 64
# AUROC: 0.8527238351035167
# AUPRC: 0.20962847148083016
# External Validation: train_size = 0.2, epoch = 9, batch_size = 64
# AUROC: 0.8501332803304733
# AUPRC: 0.21104873546570774
# External Validation: train_size = 0.2, epoch = 10, batch_size = 64
# AUROC: 0.8405398426604237
# AUPRC: 0.2024413818684017
#
# Internal Validation:
# AUROC: 0.921622071073398
# AUPRC: 0.14331849019092788
# External Validation: train_size = 0.2, epoch = 1, batch_size = 128
# AUROC: 0.8946564825457156
# AUPRC: 0.2276068195635495
# External Validation: train_size = 0.2, epoch = 2, batch_size = 128
# AUROC: 0.8868288292899988
# AUPRC: 0.22834141687027518
# External Validation: train_size = 0.2, epoch = 3, batch_size = 128
# AUROC: 0.8525450704274169
# AUPRC: 0.18430267147203233
# External Validation: train_size = 0.2, epoch = 4, batch_size = 128
# AUROC: 0.8474695400188923
# AUPRC: 0.19743547777388226
# External Validation: train_size = 0.2, epoch = 5, batch_size = 128
# AUROC: 0.8556077985656702
# AUPRC: 0.20376973386404656
# External Validation: train_size = 0.2, epoch = 6, batch_size = 128
# AUROC: 0.8405018501677401
# AUPRC: 0.18852348537007632
# External Validation: train_size = 0.2, epoch = 7, batch_size = 128
# AUROC: 0.8288418875096948
# AUPRC: 0.15871017685198838
# External Validation: train_size = 0.2, epoch = 8, batch_size = 128
# AUROC: 0.8477094926042614
# AUPRC: 0.19585399392330707
# External Validation: train_size = 0.2, epoch = 9, batch_size = 128
# AUROC: 0.8332490166609745
# AUPRC: 0.18928981244538123
# External Validation: train_size = 0.2, epoch = 10, batch_size = 128
# AUROC: 0.856370714480152
# AUPRC: 0.2048514820157364
#
# Internal Validation:
# AUROC: 0.898193346250035
# AUPRC: 0.14601710290553274
# External Validation: train_size = 0.2, epoch = 1, batch_size = 256
# AUROC: 0.8930148069408151
# AUPRC: 0.2199503598584482
# External Validation: train_size = 0.2, epoch = 2, batch_size = 256
# AUROC: 0.8911195814373747
# AUPRC: 0.21851114100850028
# External Validation: train_size = 0.2, epoch = 3, batch_size = 256
# AUROC: 0.8824855541878258
# AUPRC: 0.21054963967210813
# External Validation: train_size = 0.2, epoch = 4, batch_size = 256
# AUROC: 0.8784258897108599
# AUPRC: 0.20396559996615943
# External Validation: train_size = 0.2, epoch = 5, batch_size = 256
# AUROC: 0.8578426902843997
# AUPRC: 0.19653629144143434
# External Validation: train_size = 0.2, epoch = 6, batch_size = 256
# AUROC: 0.8545197468980128
# AUPRC: 0.19353286584611876
# External Validation: train_size = 0.2, epoch = 7, batch_size = 256
# AUROC: 0.8482887114839441
# AUPRC: 0.18895773321638737
# External Validation: train_size = 0.2, epoch = 8, batch_size = 256
# AUROC: 0.8477830780637746
# AUPRC: 0.18894000704287695
# External Validation: train_size = 0.2, epoch = 9, batch_size = 256
# AUROC: 0.8471024792167735
# AUPRC: 0.18994429305138225
# External Validation: train_size = 0.2, epoch = 10, batch_size = 256
# AUROC: 0.845036687417233
# AUPRC: 0.195667253740894
#
# Internal Validation:
# AUROC: 0.8968219323012874
# AUPRC: 0.11301131412613197
# External Validation: train_size = 0.2, epoch = 1, batch_size = 512
# AUROC: 0.8864746326125957
# AUPRC: 0.21093979657121914
# External Validation: train_size = 0.2, epoch = 2, batch_size = 512
# AUROC: 0.886937941062846
# AUPRC: 0.2151295264491677
# External Validation: train_size = 0.2, epoch = 3, batch_size = 512
# AUROC: 0.8839637954206917
# AUPRC: 0.2131842127766559
# External Validation: train_size = 0.2, epoch = 4, batch_size = 512
# AUROC: 0.8825072832275009
# AUPRC: 0.21477337084279424
# External Validation: train_size = 0.2, epoch = 5, batch_size = 512
# AUROC: 0.8790171728733069
# AUPRC: 0.21653631479687316
# External Validation: train_size = 0.2, epoch = 6, batch_size = 512
# AUROC: 0.8731756604894872
# AUPRC: 0.2075795359661679
# External Validation: train_size = 0.2, epoch = 7, batch_size = 512
# AUROC: 0.8742963723701529
# AUPRC: 0.2031448894357119
# External Validation: train_size = 0.2, epoch = 8, batch_size = 512
# AUROC: 0.8701581234214786
# AUPRC: 0.20978751049799363
# External Validation: train_size = 0.2, epoch = 9, batch_size = 512
# AUROC: 0.870510987028963
# AUPRC: 0.2146317599771188
# External Validation: train_size = 0.2, epoch = 10, batch_size = 512
# AUROC: 0.8655802280136111
# AUPRC: 0.21021131853498257
#
# Internal Validation:
# AUROC: 0.8931510300746975
# AUPRC: 0.1099570661764219
# External Validation: train_size = 0.2, epoch = 1, batch_size = 1024
# AUROC: 0.8879965985387953
# AUPRC: 0.20524162025006892
# External Validation: train_size = 0.2, epoch = 2, batch_size = 1024
# AUROC: 0.889942614006139
# AUPRC: 0.20998832890411523
# External Validation: train_size = 0.2, epoch = 3, batch_size = 1024
# AUROC: 0.8896416068184926
# AUPRC: 0.21213898454897817
# External Validation: train_size = 0.2, epoch = 4, batch_size = 1024
# AUROC: 0.8891353068633638
# AUPRC: 0.2145278162374347
# External Validation: train_size = 0.2, epoch = 5, batch_size = 1024
# AUROC: 0.8885942137833563
# AUPRC: 0.2137769797555863
# External Validation: train_size = 0.2, epoch = 6, batch_size = 1024
# AUROC: 0.8882038909111559
# AUPRC: 0.21328557951289917
# External Validation: train_size = 0.2, epoch = 7, batch_size = 1024
# AUROC: 0.8879392765322905
# AUPRC: 0.2112872402147285
# External Validation: train_size = 0.2, epoch = 8, batch_size = 1024
# AUROC: 0.8879395431462743
# AUPRC: 0.21001704141648364
# External Validation: train_size = 0.2, epoch = 9, batch_size = 1024
# AUROC: 0.8869358748044719
# AUPRC: 0.20859046683201451
# External Validation: train_size = 0.2, epoch = 10, batch_size = 1024
# AUROC: 0.8851203002286747
# AUPRC: 0.20504258382827922
#
# Internal Validation:
# AUROC: 0.932849458781601
# AUPRC: 0.17492497027296253
# External Validation: train_size = 0.4, epoch = 1, batch_size = 32
# AUROC: 0.920981760764109
# AUPRC: 0.23559307552556322
# External Validation: train_size = 0.4, epoch = 2, batch_size = 32
# AUROC: 0.9087427704986221
# AUPRC: 0.20215813011688918
# External Validation: train_size = 0.4, epoch = 3, batch_size = 32
# AUROC: 0.9263886094390974
# AUPRC: 0.2684345058893947
# External Validation: train_size = 0.4, epoch = 4, batch_size = 32
# AUROC: 0.8982887220609925
# AUPRC: 0.18890979575829822
# External Validation: train_size = 0.4, epoch = 5, batch_size = 32
# AUROC: 0.9257669441791155
# AUPRC: 0.267284750186207
# External Validation: train_size = 0.4, epoch = 6, batch_size = 32
# AUROC: 0.9241217998313878
# AUPRC: 0.25163015372052083
# External Validation: train_size = 0.4, epoch = 7, batch_size = 32
# AUROC: 0.9136856863296119
# AUPRC: 0.25819942452850425
# External Validation: train_size = 0.4, epoch = 8, batch_size = 32
# AUROC: 0.9015961142714343
# AUPRC: 0.2379537112416222
# External Validation: train_size = 0.4, epoch = 9, batch_size = 32
# AUROC: 0.9108656255218651
# AUPRC: 0.24628185425958532
# External Validation: train_size = 0.4, epoch = 10, batch_size = 32
# AUROC: 0.8980992768776394
# AUPRC: 0.25701187159831373
#
# Internal Validation:
# AUROC: 0.9284253809602657
# AUPRC: 0.1679943592780218
# External Validation: train_size = 0.4, epoch = 1, batch_size = 64
# AUROC: 0.9174486971753782
# AUPRC: 0.27495145951505223
# External Validation: train_size = 0.4, epoch = 2, batch_size = 64
# AUROC: 0.9123558880394407
# AUPRC: 0.24800730197098164
# External Validation: train_size = 0.4, epoch = 3, batch_size = 64
# AUROC: 0.9067259810231751
# AUPRC: 0.25235058283939493
# External Validation: train_size = 0.4, epoch = 4, batch_size = 64
# AUROC: 0.906917089048263
# AUPRC: 0.24279964539905047
# External Validation: train_size = 0.4, epoch = 5, batch_size = 64
# AUROC: 0.8918895131935802
# AUPRC: 0.23762053466121888
# External Validation: train_size = 0.4, epoch = 6, batch_size = 64
# AUROC: 0.9016465933955252
# AUPRC: 0.24420797233761787
# External Validation: train_size = 0.4, epoch = 7, batch_size = 64
# AUROC: 0.8840919732016427
# AUPRC: 0.24373744023743735
# External Validation: train_size = 0.4, epoch = 8, batch_size = 64
# AUROC: 0.893792754333425
# AUPRC: 0.24168829303682837
# External Validation: train_size = 0.4, epoch = 9, batch_size = 64
# AUROC: 0.8677484956627148
# AUPRC: 0.23736445633990613
# External Validation: train_size = 0.4, epoch = 10, batch_size = 64
# AUROC: 0.8740219224303335
# AUPRC: 0.2324671187921945
#
# Internal Validation:
# AUROC: 0.9228024583307349
# AUPRC: 0.163071017391925
# External Validation: train_size = 0.4, epoch = 1, batch_size = 128
# AUROC: 0.9180418565770498
# AUPRC: 0.26188785191984415
# External Validation: train_size = 0.4, epoch = 2, batch_size = 128
# AUROC: 0.910370692556954
# AUPRC: 0.25680167521297764
# External Validation: train_size = 0.4, epoch = 3, batch_size = 128
# AUROC: 0.885418802131573
# AUPRC: 0.23732822765786943
# External Validation: train_size = 0.4, epoch = 4, batch_size = 128
# AUROC: 0.8882701006090514
# AUPRC: 0.2378689717301179
# External Validation: train_size = 0.4, epoch = 5, batch_size = 128
# AUROC: 0.8960279699481738
# AUPRC: 0.24375175744364
# External Validation: train_size = 0.4, epoch = 6, batch_size = 128
# AUROC: 0.8732883716764842
# AUPRC: 0.22522067242982405
# External Validation: train_size = 0.4, epoch = 7, batch_size = 128
# AUROC: 0.8655898895421744
# AUPRC: 0.22556098011777273
# External Validation: train_size = 0.4, epoch = 8, batch_size = 128
# AUROC: 0.8921234987805432
# AUPRC: 0.23885503905721148
# External Validation: train_size = 0.4, epoch = 9, batch_size = 128
# AUROC: 0.8862884683588534
# AUPRC: 0.23327576564415217
# External Validation: train_size = 0.4, epoch = 10, batch_size = 128
# AUROC: 0.8744509355979019
# AUPRC: 0.2105359547860977
#
# Internal Validation:
# AUROC: 0.912939226990602
# AUPRC: 0.14188276623180693
# External Validation: train_size = 0.4, epoch = 1, batch_size = 256
# AUROC: 0.9201458264691622
# AUPRC: 0.25511608935388425
# External Validation: train_size = 0.4, epoch = 2, batch_size = 256
# AUROC: 0.9154338080904852
# AUPRC: 0.24878619895653933
# External Validation: train_size = 0.4, epoch = 3, batch_size = 256
# AUROC: 0.9042314808722127
# AUPRC: 0.24854792437835335
# External Validation: train_size = 0.4, epoch = 4, batch_size = 256
# AUROC: 0.8972900668248583
# AUPRC: 0.23711737039316919
# External Validation: train_size = 0.4, epoch = 5, batch_size = 256
# AUROC: 0.8855530172144503
# AUPRC: 0.22530774500624742
# External Validation: train_size = 0.4, epoch = 6, batch_size = 256
# AUROC: 0.8754887863892128
# AUPRC: 0.22292189057241515
# External Validation: train_size = 0.4, epoch = 7, batch_size = 256
# AUROC: 0.8716515415374302
# AUPRC: 0.22616650429290838
# External Validation: train_size = 0.4, epoch = 8, batch_size = 256
# AUROC: 0.8604635860227225
# AUPRC: 0.2119735404418603
# External Validation: train_size = 0.4, epoch = 9, batch_size = 256
# AUROC: 0.8601930179175946
# AUPRC: 0.2172597594896395
# External Validation: train_size = 0.4, epoch = 10, batch_size = 256
# AUROC: 0.8590089558280346
# AUPRC: 0.21224818090995742
#
# Internal Validation:
# AUROC: 0.906583288712652
# AUPRC: 0.12757443176619088
# External Validation: train_size = 0.4, epoch = 1, batch_size = 512
# AUROC: 0.9137757173321082
# AUPRC: 0.25184858939979793
# External Validation: train_size = 0.4, epoch = 2, batch_size = 512
# AUROC: 0.9155787128702287
# AUPRC: 0.25915433971600205
# External Validation: train_size = 0.4, epoch = 3, batch_size = 512
# AUROC: 0.9123413975614663
# AUPRC: 0.25937759879745587
# External Validation: train_size = 0.4, epoch = 4, batch_size = 512
# AUROC: 0.9054864512843196
# AUPRC: 0.25770453830122486
# External Validation: train_size = 0.4, epoch = 5, batch_size = 512
# AUROC: 0.901185392362948
# AUPRC: 0.25683678612427696
# External Validation: train_size = 0.4, epoch = 6, batch_size = 512
# AUROC: 0.8975969798993315
# AUPRC: 0.25345799589903695
# External Validation: train_size = 0.4, epoch = 7, batch_size = 512
# AUROC: 0.8882610737539198
# AUPRC: 0.2479342576278163
# External Validation: train_size = 0.4, epoch = 8, batch_size = 512
# AUROC: 0.8775336066253316
# AUPRC: 0.23727616304588545
# External Validation: train_size = 0.4, epoch = 9, batch_size = 512
# AUROC: 0.8820581989856191
# AUPRC: 0.23645046079604493
# External Validation: train_size = 0.4, epoch = 10, batch_size = 512
# AUROC: 0.8701855089994183
# AUPRC: 0.2254549286013502
#
# Internal Validation:
# AUROC: 0.9000414309296945
# AUPRC: 0.11502353521700595
# External Validation: train_size = 0.4, epoch = 1, batch_size = 1024
# AUROC: 0.9101754274275292
# AUPRC: 0.2235013438016168
# External Validation: train_size = 0.4, epoch = 2, batch_size = 1024
# AUROC: 0.9174356319903194
# AUPRC: 0.2397284638101697
# External Validation: train_size = 0.4, epoch = 3, batch_size = 1024
# AUROC: 0.9171139908890527
# AUPRC: 0.24538955748581362
# External Validation: train_size = 0.4, epoch = 4, batch_size = 1024
# AUROC: 0.9167804723468232
# AUPRC: 0.25518555118595504
# External Validation: train_size = 0.4, epoch = 5, batch_size = 1024
# AUROC: 0.9149694001488481
# AUPRC: 0.25349542767161104
# External Validation: train_size = 0.4, epoch = 6, batch_size = 1024
# AUROC: 0.9126155288988829
# AUPRC: 0.24985889415359683
# External Validation: train_size = 0.4, epoch = 7, batch_size = 1024
# AUROC: 0.911047231594183
# AUPRC: 0.2572197768488062
# External Validation: train_size = 0.4, epoch = 8, batch_size = 1024
# AUROC: 0.9082995044018983
# AUPRC: 0.25772919000611466
# External Validation: train_size = 0.4, epoch = 9, batch_size = 1024
# AUROC: 0.9066114824922956
# AUPRC: 0.2586046092984163
# External Validation: train_size = 0.4, epoch = 10, batch_size = 1024
# AUROC: 0.9044889837922815
# AUPRC: 0.25659047557987724
#
# Internal Validation:
# AUROC: 0.9415580179959329
# AUPRC: 0.16011939880722684
# External Validation: train_size = 0.6, epoch = 1, batch_size = 32
# AUROC: 0.8852584538783144
# AUPRC: 0.24544349449687103
# External Validation: train_size = 0.6, epoch = 2, batch_size = 32
# AUROC: 0.9202592883487137
# AUPRC: 0.2299556379316433
# External Validation: train_size = 0.6, epoch = 3, batch_size = 32
# AUROC: 0.9180288796075162
# AUPRC: 0.262579408855174
# External Validation: train_size = 0.6, epoch = 4, batch_size = 32
# AUROC: 0.9125933580421886
# AUPRC: 0.2926449617235192
# External Validation: train_size = 0.6, epoch = 5, batch_size = 32
# AUROC: 0.9147917743080162
# AUPRC: 0.31651117202113815
# External Validation: train_size = 0.6, epoch = 6, batch_size = 32
# AUROC: 0.9133307845994622
# AUPRC: 0.30229027195404234
# ...
# AUROC: 0.90545973152997
# AUPRC: 0.20401798545301494
# External Validation: train_size = 0.4, epoch = 5, batch_size = 1024
# AUROC: 0.9071369571497743
# AUPRC: 0.21049740057451838
# External Validation: train_size = 0.4, epoch = 6, batch_size = 1024
# AUROC: 0.9076252324393828
# AUPRC: 0.2226755696738755
# External Validation: train_size = 0.4, epoch = 7, batch_size = 1024
# AUROC: 0.9056538209575893
# AUPRC: 0.2302684442785766
# External Validation: train_size = 0.4, epoch = 8, batch_size = 1024
# AUROC: 0.9058942965377214
# AUPRC: 0.23370338589156162
# External Validation: train_size = 0.4, epoch = 9, batch_size = 1024
# AUROC: 0.9062543995638075
# AUPRC: 0.23344802971706335
# External Validation: train_size = 0.4, epoch = 10, batch_size = 1024
# AUROC: 0.9040722159153332
# AUPRC: 0.24375609325457806
#
# Internal Validation:
# AUROC: 0.9333367918841253
# AUPRC: 0.1516613780556991
# External Validation: train_size = 0.6, epoch = 1, batch_size = 32
# AUROC: 0.9006463544146189
# AUPRC: 0.1903180185733714
# External Validation: train_size = 0.6, epoch = 2, batch_size = 32
# AUROC: 0.9079338631120226
# AUPRC: 0.17298046600585618
# External Validation: train_size = 0.6, epoch = 3, batch_size = 32
# AUROC: 0.9070778554949279
# AUPRC: 0.23287706198938546
# External Validation: train_size = 0.6, epoch = 4, batch_size = 32
# AUROC: 0.8910764639103526
# AUPRC: 0.21290842904095206
# External Validation: train_size = 0.6, epoch = 5, batch_size = 32
# AUROC: 0.8868202292452485
# AUPRC: 0.2029057767730889
# External Validation: train_size = 0.6, epoch = 6, batch_size = 32
# AUROC: 0.9078835097227819
# AUPRC: 0.20349705262989926
# External Validation: train_size = 0.6, epoch = 7, batch_size = 32
# AUROC: 0.8777593657303988
# AUPRC: 0.22732622965150326
# External Validation: train_size = 0.6, epoch = 8, batch_size = 32
# AUROC: 0.8895319881349105
# AUPRC: 0.22661144742266776
# External Validation: train_size = 0.6, epoch = 9, batch_size = 32
# AUROC: 0.8697202182590545
# AUPRC: 0.1804558627930557
# External Validation: train_size = 0.6, epoch = 10, batch_size = 32
# AUROC: 0.8946561321272933
# AUPRC: 0.2112801584438029
#
# Internal Validation:
# AUROC: 0.9273173903101799
# AUPRC: 0.16532155781523702
# External Validation: train_size = 0.6, epoch = 1, batch_size = 64
# AUROC: 0.9116948035302304
# AUPRC: 0.22567538769190235
# External Validation: train_size = 0.6, epoch = 2, batch_size = 64
# AUROC: 0.9128044091258651
# AUPRC: 0.21096774932343548
# External Validation: train_size = 0.6, epoch = 3, batch_size = 64
# AUROC: 0.9152470062621306
# AUPRC: 0.22120425989887896
# External Validation: train_size = 0.6, epoch = 4, batch_size = 64
# AUROC: 0.902893946607097
# AUPRC: 0.22058083986067384
# External Validation: train_size = 0.6, epoch = 5, batch_size = 64
# AUROC: 0.8977569853883619
# AUPRC: 0.23932376549790965
# External Validation: train_size = 0.6, epoch = 6, batch_size = 64
# AUROC: 0.901362288058007
# AUPRC: 0.22049791151710005
# External Validation: train_size = 0.6, epoch = 7, batch_size = 64
# AUROC: 0.902409638554217
# AUPRC: 0.2378383725656455
# External Validation: train_size = 0.6, epoch = 8, batch_size = 64
# AUROC: 0.8997280916980994
# AUPRC: 0.21799704122086422
# External Validation: train_size = 0.6, epoch = 9, batch_size = 64
# AUROC: 0.8952109349251106
# AUPRC: 0.18588650332458873
# External Validation: train_size = 0.6, epoch = 10, batch_size = 64
# AUROC: 0.8852318086937416
# AUPRC: 0.17054318701408594
#
# Internal Validation:
# AUROC: 0.9101515096126208
# AUPRC: 0.15262810674820168
# External Validation: train_size = 0.6, epoch = 1, batch_size = 128
# AUROC: 0.9119548101219468
# AUPRC: 0.20805839782043176
# External Validation: train_size = 0.6, epoch = 2, batch_size = 128
# AUROC: 0.9087413483722123
# AUPRC: 0.21551983814353334
# External Validation: train_size = 0.6, epoch = 3, batch_size = 128
# AUROC: 0.9042571501812722
# AUPRC: 0.23054348306529557
# External Validation: train_size = 0.6, epoch = 4, batch_size = 128
# AUROC: 0.9068215109678837
# AUPRC: 0.2619457064850354
# External Validation: train_size = 0.6, epoch = 5, batch_size = 128
# AUROC: 0.8977359285164977
# AUPRC: 0.2485644055275136
# External Validation: train_size = 0.6, epoch = 6, batch_size = 128
# AUROC: 0.8972104222360567
# AUPRC: 0.2504612925348038
# External Validation: train_size = 0.6, epoch = 7, batch_size = 128
# AUROC: 0.8954498846449628
# AUPRC: 0.2552462258642529
# External Validation: train_size = 0.6, epoch = 8, batch_size = 128
# AUROC: 0.8930979236093309
# AUPRC: 0.23379440917297306
# External Validation: train_size = 0.6, epoch = 9, batch_size = 128
# AUROC: 0.8975299373786941
# AUPRC: 0.22818585008704365
# External Validation: train_size = 0.6, epoch = 10, batch_size = 128
# AUROC: 0.8858012597502471
# AUPRC: 0.2377227066758986
#
# Internal Validation:
# AUROC: 0.9028432154702232
# AUPRC: 0.14393462499727633
# External Validation: train_size = 0.6, epoch = 1, batch_size = 256
# AUROC: 0.9025149229135386
# AUPRC: 0.21875648052551427
# External Validation: train_size = 0.6, epoch = 2, batch_size = 256
# AUROC: 0.9083788039696782
# AUPRC: 0.2438152278342324
# External Validation: train_size = 0.6, epoch = 3, batch_size = 256
# AUROC: 0.9080464716006884
# AUPRC: 0.25873923345847566
# External Validation: train_size = 0.6, epoch = 4, batch_size = 256
# AUROC: 0.9034972717618193
# AUPRC: 0.27616424307513227
# External Validation: train_size = 0.6, epoch = 5, batch_size = 256
# AUROC: 0.9025057677518585
# AUPRC: 0.24616127521961798
# External Validation: train_size = 0.6, epoch = 6, batch_size = 256
# AUROC: 0.8973862013403158
# AUPRC: 0.25950275901708036
# External Validation: train_size = 0.6, epoch = 7, batch_size = 256
# AUROC: 0.892519317391145
# AUPRC: 0.2358374967970028
# External Validation: train_size = 0.6, epoch = 8, batch_size = 256
# AUROC: 0.8903559526861244
# AUPRC: 0.2085300288460125
# External Validation: train_size = 0.6, epoch = 9, batch_size = 256
# AUROC: 0.8883363240194821
# AUPRC: 0.22843056433852932
# External Validation: train_size = 0.6, epoch = 10, batch_size = 256
# AUROC: 0.8855906910316036
# AUPRC: 0.2630112399315005
#
# Internal Validation:
# AUROC: 0.9043923057459251
# AUPRC: 0.15253883947131566
# External Validation: train_size = 0.6, epoch = 1, batch_size = 512
# AUROC: 0.8973266927893947
# AUPRC: 0.18247202928194628
# External Validation: train_size = 0.6, epoch = 2, batch_size = 512
# AUROC: 0.903116417035925
# AUPRC: 0.21794255271158106
# External Validation: train_size = 0.6, epoch = 3, batch_size = 512
# AUROC: 0.9109779543706742
# AUPRC: 0.22350962152467999
# External Validation: train_size = 0.6, epoch = 4, batch_size = 512
# AUROC: 0.9111207748928847
# AUPRC: 0.2087189090300729
# External Validation: train_size = 0.6, epoch = 5, batch_size = 512
# AUROC: 0.9110566887611236
# AUPRC: 0.2195800643070093
# External Validation: train_size = 0.6, epoch = 6, batch_size = 512
# AUROC: 0.910136595012268
# AUPRC: 0.22929067618535362
# External Validation: train_size = 0.6, epoch = 7, batch_size = 512
# AUROC: 0.9076537151646098
# AUPRC: 0.22816671602052058
# External Validation: train_size = 0.6, epoch = 8, batch_size = 512
# AUROC: 0.9044494085765554
# AUPRC: 0.2130085218878687
# External Validation: train_size = 0.6, epoch = 9, batch_size = 512
# AUROC: 0.9004019115977588
# AUPRC: 0.21179358348035607
# External Validation: train_size = 0.6, epoch = 10, batch_size = 512
# AUROC: 0.894576482220676
# AUPRC: 0.20631863613922713
#
# Internal Validation:
# AUROC: 0.9028122139527616
# AUPRC: 0.1319426443900857
# External Validation: train_size = 0.6, epoch = 1, batch_size = 1024
# AUROC: 0.882022009008679
# AUPRC: 0.15115081660837854
# External Validation: train_size = 0.6, epoch = 2, batch_size = 1024
# AUROC: 0.8917539458746842
# AUPRC: 0.16551630720104263
# External Validation: train_size = 0.6, epoch = 3, batch_size = 1024
# AUROC: 0.8973898634049877
# AUPRC: 0.19800539109966556
# External Validation: train_size = 0.6, epoch = 4, batch_size = 1024
# AUROC: 0.8999478155784231
# AUPRC: 0.22624436201617792
# External Validation: train_size = 0.6, epoch = 5, batch_size = 1024
# AUROC: 0.9021944922547334
# AUPRC: 0.22729594446830081
# External Validation: train_size = 0.6, epoch = 6, batch_size = 1024
# AUROC: 0.9021020251217636
# AUPRC: 0.22473980587570727
# External Validation: train_size = 0.6, epoch = 7, batch_size = 1024
# AUROC: 0.9027309847291904
# AUPRC: 0.22297360582486378
# External Validation: train_size = 0.6, epoch = 8, batch_size = 1024
# AUROC: 0.9015975757131871
# AUPRC: 0.2219927881720006
# External Validation: train_size = 0.6, epoch = 9, batch_size = 1024
# AUROC: 0.9010336177536896
# AUPRC: 0.22150744575922315
# External Validation: train_size = 0.6, epoch = 10, batch_size = 1024
# AUROC: 0.9005731131211776
# AUPRC: 0.21860970275358949
#
# Internal Validation:
# AUROC: 0.9346726347275772
# AUPRC: 0.17504964458231434
# External Validation: train_size = 0.8, epoch = 1, batch_size = 32
# AUROC: 0.9136265426447431
# AUPRC: 0.24690456079295556
# External Validation: train_size = 0.8, epoch = 2, batch_size = 32
# AUROC: 0.912740322994104
# AUPRC: 0.2560053684608108
# External Validation: train_size = 0.8, epoch = 3, batch_size = 32
# AUROC: 0.9124949646610759
# AUPRC: 0.26727595952234134
# External Validation: train_size = 0.8, epoch = 4, batch_size = 32
# AUROC: 0.9154429267220859
# AUPRC: 0.29613547533218393
# External Validation: train_size = 0.8, epoch = 5, batch_size = 32
# AUROC: 0.917746365400813
# AUPRC: 0.23664959114398426
# External Validation: train_size = 0.8, epoch = 6, batch_size = 32
# AUROC: 0.9204892518401875
# AUPRC: 0.2832783841134484
# External Validation: train_size = 0.8, epoch = 7, batch_size = 32
# AUROC: 0.915446588786758
# AUPRC: 0.24878405423401334
# External Validation: train_size = 0.8, epoch = 8, batch_size = 32
# AUROC: 0.9162888636613322
# AUPRC: 0.28266550840499877
# External Validation: train_size = 0.8, epoch = 9, batch_size = 32
# AUROC: 0.9214560369136119
# AUPRC: 0.2986276538648333
# External Validation: train_size = 0.8, epoch = 10, batch_size = 32
# AUROC: 0.9241842750942982
# AUPRC: 0.2799763592999168
#
# Internal Validation:
# AUROC: 0.9266262177503579
# AUPRC: 0.1697811783706962
# External Validation: train_size = 0.8, epoch = 1, batch_size = 64
# AUROC: 0.9186838539568608
# AUPRC: 0.27618402749600507
# External Validation: train_size = 0.8, epoch = 2, batch_size = 64
# AUROC: 0.928238180686271
# AUPRC: 0.2845513903117435
# External Validation: train_size = 0.8, epoch = 3, batch_size = 64
# AUROC: 0.9284286080492181
# AUPRC: 0.27713495553984063
# External Validation: train_size = 0.8, epoch = 4, batch_size = 64
# AUROC: 0.9316146043139123
# AUPRC: 0.33033151146913375
# External Validation: train_size = 0.8, epoch = 5, batch_size = 64
# AUROC: 0.9356978064232614
# AUPRC: 0.32480192498777516
# External Validation: train_size = 0.8, epoch = 6, batch_size = 64
# AUROC: 0.935617241000476
# AUPRC: 0.2859413893890984
# External Validation: train_size = 0.8, epoch = 7, batch_size = 64
# AUROC: 0.922466766763101
# AUPRC: 0.2855816680333294
# External Validation: train_size = 0.8, epoch = 8, batch_size = 64
# AUROC: 0.934024242868129
# AUPRC: 0.28132819446353646
# External Validation: train_size = 0.8, epoch = 9, batch_size = 64
# AUROC: 0.9380378657487092
# AUPRC: 0.2993587257928937
# External Validation: train_size = 0.8, epoch = 10, batch_size = 64
# AUROC: 0.9169919800783682
# AUPRC: 0.26588821815756175
#
# Internal Validation:
# AUROC: 0.918274982384687
# AUPRC: 0.15032491226326328
# External Validation: train_size = 0.8, epoch = 1, batch_size = 128
# AUROC: 0.9310469842897424
# AUPRC: 0.3086460548802196
# External Validation: train_size = 0.8, epoch = 2, batch_size = 128
# AUROC: 0.9318233420002199
# AUPRC: 0.30789831189119427
# External Validation: train_size = 0.8, epoch = 3, batch_size = 128
# AUROC: 0.9319991211044788
# AUPRC: 0.32083727451125826
# External Validation: train_size = 0.8, epoch = 4, batch_size = 128
# AUROC: 0.9324092723477496
# AUPRC: 0.3170578676511321
# External Validation: train_size = 0.8, epoch = 5, batch_size = 128
# AUROC: 0.9309078258322041
# AUPRC: 0.3189022324066743
# External Validation: train_size = 0.8, epoch = 6, batch_size = 128
# AUROC: 0.9353242758267111
# AUPRC: 0.2846765608954508
# External Validation: train_size = 0.8, epoch = 7, batch_size = 128
# AUROC: 0.9304061229721317
# AUPRC: 0.3230453876611328
# External Validation: train_size = 0.8, epoch = 8, batch_size = 128
# AUROC: 0.9302669645145933
# AUPRC: 0.29007619813601093
# External Validation: train_size = 0.8, epoch = 9, batch_size = 128
# AUROC: 0.9261947485992602
# AUPRC: 0.27340287080404513
# External Validation: train_size = 0.8, epoch = 10, batch_size = 128
# AUROC: 0.9194748599260263
# AUPRC: 0.23927499763154145
#
# Internal Validation:
# AUROC: 0.9034340362972217
# AUPRC: 0.14017764707121136
# External Validation: train_size = 0.8, epoch = 1, batch_size = 256
# AUROC: 0.931900245358333
# AUPRC: 0.33933255814050844
# External Validation: train_size = 0.8, epoch = 2, batch_size = 256
# AUROC: 0.9353389240853994
# AUPRC: 0.3397403064478416
# External Validation: train_size = 0.8, epoch = 3, batch_size = 256
# AUROC: 0.9367085362727506
# AUPRC: 0.3480072942080443
# External Validation: train_size = 0.8, epoch = 4, batch_size = 256
# AUROC: 0.9358845717215365
# AUPRC: 0.339408151471691
# External Validation: train_size = 0.8, epoch = 5, batch_size = 256
# AUROC: 0.9372688321675761
# AUPRC: 0.30233762738793957
# External Validation: train_size = 0.8, epoch = 6, batch_size = 256
# AUROC: 0.9348555315486872
# AUPRC: 0.3257112105134869
# External Validation: train_size = 0.8, epoch = 7, batch_size = 256
# AUROC: 0.9339802980920643
# AUPRC: 0.3148304414795675
# External Validation: train_size = 0.8, epoch = 8, batch_size = 256
# AUROC: 0.9335664847841213
# AUPRC: 0.3050474190021896
# External Validation: train_size = 0.8, epoch = 9, batch_size = 256
# AUROC: 0.9346211594096752
# AUPRC: 0.3208987248338631
# External Validation: train_size = 0.8, epoch = 10, batch_size = 256
# AUROC: 0.9338740982165744
# AUPRC: 0.29900609891509783
#
# Internal Validation:
# AUROC: 0.9086127233094855
# AUPRC: 0.12342793351762764
# External Validation: train_size = 0.8, epoch = 1, batch_size = 512
# AUROC: 0.9298677994653386
# AUPRC: 0.22906452181569675
# External Validation: train_size = 0.8, epoch = 2, batch_size = 512
# AUROC: 0.9358625993335042
# AUPRC: 0.3056521796212345
# External Validation: train_size = 0.8, epoch = 3, batch_size = 512
# AUROC: 0.9347969385139342
# AUPRC: 0.32781946023226816
# External Validation: train_size = 0.8, epoch = 4, batch_size = 512
# AUROC: 0.9360420405024353
# AUPRC: 0.3167696688382393
# External Validation: train_size = 0.8, epoch = 5, batch_size = 512
# AUROC: 0.9357820339107188
# AUPRC: 0.31867588004468517
# External Validation: train_size = 0.8, epoch = 6, batch_size = 512
# AUROC: 0.9360786611491559
# AUPRC: 0.3186116614620857
# External Validation: train_size = 0.8, epoch = 7, batch_size = 512
# AUROC: 0.9369795290584833
# AUPRC: 0.3255989520666715
# External Validation: train_size = 0.8, epoch = 8, batch_size = 512
# AUROC: 0.9356721719705571
# AUPRC: 0.3064786158605964
# External Validation: train_size = 0.8, epoch = 9, batch_size = 512
# AUROC: 0.9369575566704509
# AUPRC: 0.3011119240177027
# External Validation: train_size = 0.8, epoch = 10, batch_size = 512
# AUROC: 0.9365400812978358
# AUPRC: 0.3130844329068846
#
# Internal Validation:
# AUROC: 0.9094051435997458
# AUPRC: 0.12366684647453759
# External Validation: train_size = 0.8, epoch = 1, batch_size = 1024
# AUROC: 0.9299996337935327
# AUPRC: 0.2105677429773906
# External Validation: train_size = 0.8, epoch = 2, batch_size = 1024
# AUROC: 0.9345882008276267
# AUPRC: 0.2457998624914137
# External Validation: train_size = 0.8, epoch = 3, batch_size = 1024
# AUROC: 0.9366096605266049
# AUPRC: 0.28142075230542485
# External Validation: train_size = 0.8, epoch = 4, batch_size = 1024
# AUROC: 0.9381550518182151
# AUPRC: 0.28756638381851934
# External Validation: train_size = 0.8, epoch = 5, batch_size = 1024
# AUROC: 0.9383161826637857
# AUPRC: 0.3083143336746428
# External Validation: train_size = 0.8, epoch = 6, batch_size = 1024
# AUROC: 0.9376863075401912
# AUPRC: 0.3135795870009378
# External Validation: train_size = 0.8, epoch = 7, batch_size = 1024
# AUROC: 0.9382575896290328
# AUPRC: 0.31799745868047674
# External Validation: train_size = 0.8, epoch = 8, batch_size = 1024
# AUROC: 0.9379573003259237
# AUPRC: 0.31078356482383895
# External Validation: train_size = 0.8, epoch = 9, batch_size = 1024
# AUROC: 0.9382942102757534
# AUPRC: 0.3038080352838204
# External Validation: train_size = 0.8, epoch = 10, batch_size = 1024
# AUROC: 0.9376277145054381
# AUPRC: 0.29943307434037314

# %%
result_amc = transfer_test(build_set=amc_set, 
                            val_set_1=snuh_set, val_set_2=eumc_set, val_set_3=brmh_set, 
                            variable=var_list)
# Out:
# /home/khl256/anaconda3/envs/deeplearning/lib/python3.7/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# HBox(children=(FloatProgress(value=0.0, description='data_set', max=3.0, style=ProgressStyle(description_width…
# /home/khl256/anaconda3/envs/deeplearning/lib/python3.7/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# HBox(children=(FloatProgress(value=0.0, description='train_size', max=4.0, style=ProgressStyle(description_wid…
# Internal Validation:
# AUROC: 0.7952077547241737
# AUPRC: 0.044411342241986285
# External Validation: train_size = 0.2, epoch = 1, batch_size = 32
# AUROC: 0.8600806608411615
# AUPRC: 0.01915425984510568
# External Validation: train_size = 0.2, epoch = 2, batch_size = 32
# AUROC: 0.9172383229112465
# AUPRC: 0.10198318910471153
# External Validation: train_size = 0.2, epoch = 3, batch_size = 32
# AUROC: 0.9104809097120763
# AUPRC: 0.08330397756180911
# External Validation: train_size = 0.2, epoch = 4, batch_size = 32
# AUROC: 0.9149737165447142
# AUPRC: 0.08401820424305481
# External Validation: train_size = 0.2, epoch = 5, batch_size = 32
# AUROC: 0.9244397332246543
# AUPRC: 0.1137943436926821
# External Validation: train_size = 0.2, epoch = 6, batch_size = 32
# AUROC: 0.9271119981402016
# AUPRC: 0.09665414913674858
# External Validation: train_size = 0.2, epoch = 7, batch_size = 32
# AUROC: 0.9299187819600234
# AUPRC: 0.09947015252724442
# External Validation: train_size = 0.2, epoch = 8, batch_size = 32
# AUROC: 0.9177297632881396
# AUPRC: 0.10576593485299685
# External Validation: train_size = 0.2, epoch = 9, batch_size = 32
# AUROC: 0.9148011981401792
# AUPRC: 0.13339319521518064
# External Validation: train_size = 0.2, epoch = 10, batch_size = 32
# AUROC: 0.9232127623554909
# AUPRC: 0.12573876880926824
#
# Internal Validation:
# AUROC: 0.9340630615912432
# AUPRC: 0.13527755916337988
# External Validation: train_size = 0.2, epoch = 1, batch_size = 64
# AUROC: 0.9337388708234148
# AUPRC: 0.13068231404261818
# External Validation: train_size = 0.2, epoch = 2, batch_size = 64
# AUROC: 0.9159539038903307
# AUPRC: 0.11656339597576562
# External Validation: train_size = 0.2, epoch = 3, batch_size = 64
# AUROC: 0.9159195517136334
# AUPRC: 0.12965398097240083
# External Validation: train_size = 0.2, epoch = 4, batch_size = 64
# AUROC: 0.9145436690402887
# AUPRC: 0.131211777061287
# External Validation: train_size = 0.2, epoch = 5, batch_size = 64
# AUROC: 0.9011522007361197
# AUPRC: 0.08664336149975288
# External Validation: train_size = 0.2, epoch = 6, batch_size = 64
# AUROC: 0.897240171262603
# AUPRC: 0.12288133611306937
# External Validation: train_size = 0.2, epoch = 7, batch_size = 64
# AUROC: 0.9193855527942512
# AUPRC: 0.13344184453018768
# External Validation: train_size = 0.2, epoch = 8, batch_size = 64
# AUROC: 0.8926481347839805
# AUPRC: 0.12356519257557416
# External Validation: train_size = 0.2, epoch = 9, batch_size = 64
# AUROC: 0.897130005257196
# AUPRC: 0.11868585412780729
# External Validation: train_size = 0.2, epoch = 10, batch_size = 64
# AUROC: 0.8739384703248423
# AUPRC: 0.1253416516182124
#
# Internal Validation:
# AUROC: 0.880596852366171
# AUPRC: 0.05232750444743979
# External Validation: train_size = 0.2, epoch = 1, batch_size = 128
# AUROC: 0.9213956264774816
# AUPRC: 0.12490922857981535
# External Validation: train_size = 0.2, epoch = 2, batch_size = 128
# AUROC: 0.9084671662602145
# AUPRC: 0.1297257809160767
# External Validation: train_size = 0.2, epoch = 3, batch_size = 128
# AUROC: 0.8943961622973695
# AUPRC: 0.12277986265574843
# External Validation: train_size = 0.2, epoch = 4, batch_size = 128
# AUROC: 0.8905852703006242
# AUPRC: 0.12969661951196582
# External Validation: train_size = 0.2, epoch = 5, batch_size = 128
# AUROC: 0.8767032369772172
# AUPRC: 0.12284844621207754
# External Validation: train_size = 0.2, epoch = 6, batch_size = 128
# AUROC: 0.882776030709791
# AUPRC: 0.12982246697021832
# External Validation: train_size = 0.2, epoch = 7, batch_size = 128
# AUROC: 0.88455829256327
# AUPRC: 0.13171660236057892
# External Validation: train_size = 0.2, epoch = 8, batch_size = 128
# AUROC: 0.8828060060982128
# AUPRC: 0.12725688939330654
# External Validation: train_size = 0.2, epoch = 9, batch_size = 128
# AUROC: 0.8903618296478812
# AUPRC: 0.12252695775083092
# External Validation: train_size = 0.2, epoch = 10, batch_size = 128
# AUROC: 0.9003958299981365
# AUPRC: 0.12238392590438342
#
# Internal Validation:
# AUROC: 0.9356532157054948
# AUPRC: 0.14491606580628275
# External Validation: train_size = 0.2, epoch = 1, batch_size = 256
# AUROC: 0.907183689932158
# AUPRC: 0.12300242544437479
# External Validation: train_size = 0.2, epoch = 2, batch_size = 256
# AUROC: 0.9065630725771936
# AUPRC: 0.13164145258909365
# External Validation: train_size = 0.2, epoch = 3, batch_size = 256
# AUROC: 0.8992748166841149
# AUPRC: 0.12933000210498205
# External Validation: train_size = 0.2, epoch = 4, batch_size = 256
# AUROC: 0.8956310169966961
# AUPRC: 0.1313039656199713
# External Validation: train_size = 0.2, epoch = 5, batch_size = 256
# AUROC: 0.8958535654579829
# AUPRC: 0.1310904381091749
# External Validation: train_size = 0.2, epoch = 6, batch_size = 256
# AUROC: 0.8898802370446085
# AUPRC: 0.12628716928112327
# External Validation: train_size = 0.2, epoch = 7, batch_size = 256
# AUROC: 0.8857064644096692
# AUPRC: 0.12599890696153201
# External Validation: train_size = 0.2, epoch = 8, batch_size = 256
# AUROC: 0.8720381810808614
# AUPRC: 0.12556417040867615
# External Validation: train_size = 0.2, epoch = 9, batch_size = 256
# AUROC: 0.8674983237742595
# AUPRC: 0.12237541030352365
# External Validation: train_size = 0.2, epoch = 10, batch_size = 256
# AUROC: 0.8772757657738186
# AUPRC: 0.12447728625399147
#
# Internal Validation:
# AUROC: 0.8027609867668682
# AUPRC: 0.025812040787368987
# External Validation: train_size = 0.2, epoch = 1, batch_size = 512
# AUROC: 0.9105431835534661
# AUPRC: 0.1201551077936258
# External Validation: train_size = 0.2, epoch = 2, batch_size = 512
# AUROC: 0.9181745852586292
# AUPRC: 0.12375282947195718
# External Validation: train_size = 0.2, epoch = 3, batch_size = 512
# AUROC: 0.9168861261254588
# AUPRC: 0.13111742110406238
# External Validation: train_size = 0.2, epoch = 4, batch_size = 512
# AUROC: 0.9155019892783276
# AUPRC: 0.13215040156224606
# External Validation: train_size = 0.2, epoch = 5, batch_size = 512
# AUROC: 0.9098489519864643
# AUPRC: 0.1326320761847546
# External Validation: train_size = 0.2, epoch = 6, batch_size = 512
# AUROC: 0.9085594996590314
# AUPRC: 0.13276694530561375
# External Validation: train_size = 0.2, epoch = 7, batch_size = 512
# AUROC: 0.9071503533947913
# AUPRC: 0.133291486979861
# External Validation: train_size = 0.2, epoch = 8, batch_size = 512
# AUROC: 0.9022109850988876
# AUPRC: 0.13158558633550985
# External Validation: train_size = 0.2, epoch = 9, batch_size = 512
# AUROC: 0.9006701143413491
# AUPRC: 0.13098723553332695
# External Validation: train_size = 0.2, epoch = 10, batch_size = 512
# AUROC: 0.8909413669169908
# AUPRC: 0.13284257900625085
#
# Internal Validation:
# AUROC: 0.9442465828023743
# AUPRC: 0.16568733009925768
# External Validation: train_size = 0.2, epoch = 1, batch_size = 1024
# AUROC: 0.8985684647803495
# AUPRC: 0.1064116232211364
# External Validation: train_size = 0.2, epoch = 2, batch_size = 1024
# AUROC: 0.9057776354760462
# AUPRC: 0.10729671004886114
# External Validation: train_size = 0.2, epoch = 3, batch_size = 1024
# AUROC: 0.9054354660244235
# AUPRC: 0.11304724920115221
# External Validation: train_size = 0.2, epoch = 4, batch_size = 1024
# AUROC: 0.9044362677061427
# AUPRC: 0.11546267970536542
# External Validation: train_size = 0.2, epoch = 5, batch_size = 1024
# AUROC: 0.9066323156122227
# AUPRC: 0.12035681177138507
# External Validation: train_size = 0.2, epoch = 6, batch_size = 1024
# AUROC: 0.9046377795273708
# AUPRC: 0.12270241077989004
# External Validation: train_size = 0.2, epoch = 7, batch_size = 1024
# AUROC: 0.904269652354513
# AUPRC: 0.12354530837943845
# External Validation: train_size = 0.2, epoch = 8, batch_size = 1024
# AUROC: 0.9036680010820768
# AUPRC: 0.12433476477660874
# External Validation: train_size = 0.2, epoch = 9, batch_size = 1024
# AUROC: 0.9018695787795797
# AUPRC: 0.12524038489626144
# External Validation: train_size = 0.2, epoch = 10, batch_size = 1024
# AUROC: 0.9018658248419433
# AUPRC: 0.12550741104673982
#
# Internal Validation:
# AUROC: 0.860534771006916
# AUPRC: 0.065611938090789
# External Validation: train_size = 0.4, epoch = 1, batch_size = 32
# AUROC: 0.919854833554308
# AUPRC: 0.058026133576444136
# External Validation: train_size = 0.4, epoch = 2, batch_size = 32
# AUROC: 0.9095850841437122
# AUPRC: 0.12697655590530232
# External Validation: train_size = 0.4, epoch = 3, batch_size = 32
# AUROC: 0.9109979674062278
# AUPRC: 0.10910877706401104
# External Validation: train_size = 0.4, epoch = 4, batch_size = 32
# AUROC: 0.937301429803243
# AUPRC: 0.12699683161531067
# External Validation: train_size = 0.4, epoch = 5, batch_size = 32
# AUROC: 0.9290358446045026
# AUPRC: 0.12482143367963014
# External Validation: train_size = 0.4, epoch = 6, batch_size = 32
# AUROC: 0.9277147085640656
# AUPRC: 0.10414179504037174
# External Validation: train_size = 0.4, epoch = 7, batch_size = 32
# AUROC: 0.9339719769185512
# AUPRC: 0.134331036575365
# External Validation: train_size = 0.4, epoch = 8, batch_size = 32
# AUROC: 0.9216101692377383
# AUPRC: 0.12608811299124434
# External Validation: train_size = 0.4, epoch = 9, batch_size = 32
# AUROC: 0.9271364445201324
# AUPRC: 0.13113868902195847
# External Validation: train_size = 0.4, epoch = 10, batch_size = 32
# AUROC: 0.9241890238339139
# AUPRC: 0.1274819007392602
#
# Internal Validation:
# AUROC: 0.9203180308228504
# AUPRC: 0.11658219081664614
# External Validation: train_size = 0.4, epoch = 1, batch_size = 64
# AUROC: 0.9212227865321347
# AUPRC: 0.10155067301956627
# External Validation: train_size = 0.4, epoch = 2, batch_size = 64
# AUROC: 0.917003512368356
# AUPRC: 0.12286609788415552
# External Validation: train_size = 0.4, epoch = 3, batch_size = 64
# AUROC: 0.917650963660274
# AUPRC: 0.12317204418450972
# External Validation: train_size = 0.4, epoch = 4, batch_size = 64
# AUROC: 0.9204138417619459
# AUPRC: 0.1359430625262763
# External Validation: train_size = 0.4, epoch = 5, batch_size = 64
# AUROC: 0.9184441064663075
# AUPRC: 0.13328580062850462
# External Validation: train_size = 0.4, epoch = 6, batch_size = 64
# AUROC: 0.9154936511641045
# AUPRC: 0.13178467898099228
# External Validation: train_size = 0.4, epoch = 7, batch_size = 64
# AUROC: 0.9164070406285169
# AUPRC: 0.13420580007085056
# External Validation: train_size = 0.4, epoch = 8, batch_size = 64
# AUROC: 0.9148469585261829
# AUPRC: 0.1395429752989763
# External Validation: train_size = 0.4, epoch = 9, batch_size = 64
# AUROC: 0.9159057799651857
# AUPRC: 0.1281882316208698
# External Validation: train_size = 0.4, epoch = 10, batch_size = 64
# AUROC: 0.9174872940429091
# AUPRC: 0.1350269472529036
#
# Internal Validation:
# AUROC: 0.9317867450852257
# AUPRC: 0.11098145631082458
# External Validation: train_size = 0.4, epoch = 1, batch_size = 128
# AUROC: 0.9168971111454058
# AUPRC: 0.13415461039495416
# External Validation: train_size = 0.4, epoch = 2, batch_size = 128
# AUROC: 0.9157070126182129
# AUPRC: 0.13564757353102
# External Validation: train_size = 0.4, epoch = 3, batch_size = 128
# AUROC: 0.916281493374455
# AUPRC: 0.13396197405512436
# External Validation: train_size = 0.4, epoch = 4, batch_size = 128
# AUROC: 0.9101092841081354
# AUPRC: 0.13214564647594665
# External Validation: train_size = 0.4, epoch = 5, batch_size = 128
# AUROC: 0.9105319542068462
# AUPRC: 0.13741878368398927
# External Validation: train_size = 0.4, epoch = 6, batch_size = 128
# AUROC: 0.914314842606248
# AUPRC: 0.1355887688589716
# External Validation: train_size = 0.4, epoch = 7, batch_size = 128
# AUROC: 0.9174174379815332
# AUPRC: 0.13620219590459048
# External Validation: train_size = 0.4, epoch = 8, batch_size = 128
# AUROC: 0.9123631652721741
# AUPRC: 0.135263060863321
# External Validation: train_size = 0.4, epoch = 9, batch_size = 128
# AUROC: 0.9063993163329621
# AUPRC: 0.141163256574328
# External Validation: train_size = 0.4, epoch = 10, batch_size = 128
# AUROC: 0.9206932160960024
# AUPRC: 0.136701312782384
#
# Internal Validation:
# AUROC: 0.9059086205957632
# AUPRC: 0.04484429310340356
# External Validation: train_size = 0.4, epoch = 1, batch_size = 256
# AUROC: 0.9209008377336929
# AUPRC: 0.12190005625837574
# External Validation: train_size = 0.4, epoch = 2, batch_size = 256
# AUROC: 0.9240498108256332
# AUPRC: 0.12781586245194965
# External Validation: train_size = 0.4, epoch = 3, batch_size = 256
# AUROC: 0.9161071227428297
# AUPRC: 0.12836129643535615
# External Validation: train_size = 0.4, epoch = 4, batch_size = 256
# AUROC: 0.9192342446032249
# AUPRC: 0.13473870082665182
# External Validation: train_size = 0.4, epoch = 5, batch_size = 256
# AUROC: 0.9082092052280843
# AUPRC: 0.13080234429912496
# External Validation: train_size = 0.4, epoch = 6, batch_size = 256
# AUROC: 0.913844067854812
# AUPRC: 0.13514872891759994
# External Validation: train_size = 0.4, epoch = 7, batch_size = 256
# AUROC: 0.9063562327718163
# AUPRC: 0.1408449651023533
# External Validation: train_size = 0.4, epoch = 8, batch_size = 256
# AUROC: 0.9147354264064698
# AUPRC: 0.13291492960573303
# External Validation: train_size = 0.4, epoch = 9, batch_size = 256
# AUROC: 0.9099782266303125
# AUPRC: 0.1261921757447126
# External Validation: train_size = 0.4, epoch = 10, batch_size = 256
# AUROC: 0.9058433926527556
# AUPRC: 0.12488916328934993
#
# Internal Validation:
# AUROC: 0.8120786363883897
# AUPRC: 0.036535379592967765
# External Validation: train_size = 0.4, epoch = 1, batch_size = 512
# AUROC: 0.9082164823170731
# AUPRC: 0.1298794837419939
# External Validation: train_size = 0.4, epoch = 2, batch_size = 512
# AUROC: 0.912597948719382
# AUPRC: 0.1333506456263778
# External Validation: train_size = 0.4, epoch = 3, batch_size = 512
# AUROC: 0.9125973797288851
# AUPRC: 0.1340952334675795
# External Validation: train_size = 0.4, epoch = 4, batch_size = 512
# AUROC: 0.9113429054172089
# AUPRC: 0.13412778369902173
# External Validation: train_size = 0.4, epoch = 5, batch_size = 512
# AUROC: 0.9123387186453793
# AUPRC: 0.13658509874836164
# External Validation: train_size = 0.4, epoch = 6, batch_size = 512
# AUROC: 0.9133836746843751
# AUPRC: 0.13673214392458363
# External Validation: train_size = 0.4, epoch = 7, batch_size = 512
# AUROC: 0.910556850036665
# AUPRC: 0.13545013929168181
# External Validation: train_size = 0.4, epoch = 8, batch_size = 512
# AUROC: 0.9083958640579883
# AUPRC: 0.13691049709698233
# External Validation: train_size = 0.4, epoch = 9, batch_size = 512
# AUROC: 0.9053360427928769
# AUPRC: 0.1349699059888671
# External Validation: train_size = 0.4, epoch = 10, batch_size = 512
# AUROC: 0.9022748739186934
# AUPRC: 0.1332876638745321
#
# Internal Validation:
# AUROC: 0.9423296846920437
# AUPRC: 0.12910332476372127
# External Validation: train_size = 0.4, epoch = 1, batch_size = 1024
# AUROC: 0.9093853285500864
# AUPRC: 0.11769354840779375
# External Validation: train_size = 0.4, epoch = 2, batch_size = 1024
# AUROC: 0.9141762185530433
# AUPRC: 0.12210464063189516
# External Validation: train_size = 0.4, epoch = 3, batch_size = 1024
# AUROC: 0.9173656498640113
# AUPRC: 0.12438710649484462
# External Validation: train_size = 0.4, epoch = 4, batch_size = 1024
# AUROC: 0.9182215712882205
# AUPRC: 0.12383602228247476
# External Validation: train_size = 0.4, epoch = 5, batch_size = 1024
# AUROC: 0.9189209105205545
# AUPRC: 0.12646769465186306
# External Validation: train_size = 0.4, epoch = 6, batch_size = 1024
# AUROC: 0.9189133539274619
# AUPRC: 0.12750513582299183
# External Validation: train_size = 0.4, epoch = 7, batch_size = 1024
# AUROC: 0.918334321247243
# AUPRC: 0.12878183637371793
# External Validation: train_size = 0.4, epoch = 8, batch_size = 1024
# AUROC: 0.9187622420301901
# AUPRC: 0.12992344260358768
# External Validation: train_size = 0.4, epoch = 9, batch_size = 1024
# AUROC: 0.918750083601674
# AUPRC: 0.12812266810276382
# External Validation: train_size = 0.4, epoch = 10, batch_size = 1024
# AUROC: 0.9181826403594743
# AUPRC: 0.12910573643393722
#
# Internal Validation:
# AUROC: 0.7791428415836192
# AUPRC: 0.030295607520659656
# External Validation: train_size = 0.6, epoch = 1, batch_size = 32
# AUROC: 0.9120437893746152
# AUPRC: 0.06378970296205098
# External Validation: train_size = 0.6, epoch = 2, batch_size = 32
# AUROC: 0.9358646699539027
# AUPRC: 0.11716213465176359
# External Validation: train_size = 0.6, epoch = 3, batch_size = 32
# AUROC: 0.9333885357463624
# AUPRC: 0.10986143497484302
# External Validation: train_size = 0.6, epoch = 4, batch_size = 32
# AUROC: 0.9336185383340035
# AUPRC: 0.1469430375066826

# %%
result_eumc = transfer_test(build_set=eumc_set, 
                            val_set_1=amc_set, val_set_2=snuh_set, val_set_3=brmh_set, 
                            variable=var_list)

# %%
result_brmh = transfer_test(build_set=brmh_set, 
                            val_set_1=amc_set, val_set_2=eumc_set, val_set_3=snuh_set, 
                            variable=var_list)

# %%
np.savez('./transfer_result' , snuh = np.array(result_snuh), amc = np.array(result_amc), eumc = np.array(result_eumc), brmh = np.array(result_brmh))
